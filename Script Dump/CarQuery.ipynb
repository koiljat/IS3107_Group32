# %%
import requests
from tqdm import tqdm
import pandas as pd
import re
import os

# %% [markdown]
# # CarQuery

# %%
BASE_URL = 'https://www.carqueryapi.com/api/0.3'

header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}


def get_makes(year, sold_in_us=1):
    params = {
        'cmd': 'getMakes',
        'year': year,
        'sold_in_us': sold_in_us
    }
    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Makes']  # Adjust based on the actual key for makes

def get_models(make, year=None, sold_in_us=1, body=None):
    params = {
        'cmd': 'getModels',
        'make': make,
        'sold_in_us': sold_in_us
    }
    if year:
        params['year'] = year
    if body:
        params['body'] = body

    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Models']  # Adjust based on the actual key for models

def get_trims(make, model, year=None, trim=None, body=None):
    params = {
        'cmd': 'getTrims',
        'make': make,
        'model' : model
    }
    if year:
        params['year'] = year
    if trim:
        params['trim'] = trim
    if body:
        params['body'] = body

    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Trims']  # Adjust based on the actual key for trims

def get_model(model_id):
    params = {
        'cmd': 'getModel',
        'model': model_id
    }
    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()  # Adjust based on how the API returns data for a single model

def extract_car_info(car_string):
    pattern = re.compile(r'^(.*?)\s(.*?)(?:\s\((\d{4})-?\d*\)|\s(\d{4})|$)')
    match = pattern.search(car_string)
    if match:
        make = match.group(1)
        model = match.group(2)
        year = match.group(3) if match.group(3) else match.group(4)
        return make, model, year
    else:
        return None, None, None
    
def process_chunk(chunk):    
    # Set the columns that you want to keep from the API data
    api_columns = [
        'model_make_id', 'model_name', 'model_trim', 'model_year', 'model_body',
        'model_engine_cyl', 'model_engine_fuel', 'model_drive', 'model_transmission_type',
        'model_seats', 'model_weight_kg', 'model_fuel_cap_l'
    ]

    api_data = []

    # Process each row in the DataFrame
    for index, row in chunk.iterrows():
        name = row['model']
        reg_date = row['reg_date']

        name_split = name.split(' ')
        make = name_split[0]
        model = name_split[1]

        year = pd.to_datetime(reg_date).year if pd.notnull(reg_date) else None

        model_info = get_trims(make=make, model=model, year= year)

        if model_info:
            first_trim = model_info[0]  # Safely get the first trim
            # Select only the desired columns
            selected_trim_info = {key: first_trim.get(key, pd.NA) for key in api_columns}
            print(selected_trim_info)
            api_data.append(selected_trim_info)
        else:
            print("Nothing found")
            placeholder = {key: pd.NA for key in api_columns}
            api_data.append(placeholder)
    
    result_df = pd.concat([chunk, pd.DataFrame(api_data)], axis = 1)
    
    return result_df

# %% [markdown]
# # Loading the data

# %%
data_filename = "../Datasets/merged_dataset.csv"
start_row = 300 
chunk_size = 100

chunk = pd.read_csv(data_filename, skiprows= range(1,start_row + 1), nrows=chunk_size, header=0)

print(chunk)
api_df = process_chunk(chunk)

output_filename = '../Datasets/CarQuery.csv'

# Check if the file exists and has content
if os.path.exists(output_filename) and os.path.getsize(output_filename) > 0:
    header = False  # Don't write header if file already exists
else:
    header = True  # Write header if file doesn't exist

# Append or write the DataFrame to the CSV file
api_df.to_csv(output_filename, mode='a', index=False, header=header)
# Out:
#                                             model   price  depreciation  \
# 0                               Honda Fit 1.3A G    58800         11700
# 1                      Toyota Corolla Altis 1.6A    61800         12350
# 2                       Toyota Prius Hybrid 1.5A    40800         12150
# 3                              Honda HR-V 1.5A LX   76800         14420
# 4                            Mazda 5 2.0A Sunroof   60998         14460
# ..                                            ...     ...           ...
# 95                         Land Rover Defender 90  285800         28480
# 96                    Honda Fit Hybrid 1.5A e-HEV  138800         16250
# 97                        Jaguar XE 2.0A Prestige   59888         19510
# 98  Peugeot 5008 Diesel 1.6A BlueHDi EAT6 Sunroof   45800         16400
# 99                      Toyota Corolla Altis 1.6A   40000         14450
#
#     mileage  eng_cap  power   reg_date  coe_left  no_of_owner    omv    arf  \
# 0    108415     1339     73  28-Apr-09      5.02            1  14071  14071
# 1    112803     1598     90  10-Apr-14      5.00            1  18544  13544
# 2    108000     1497     54  30-Aug-12      3.36            3  22923  13754
# 3     70000     1496     96   8-Oct-18      4.54            1  21733  22427
# 4    123317     1998    111  31-Oct-17      3.61            1  17616  17616
# ..      ...      ...    ...        ...       ...          ...    ...    ...
# 95     4000     1997    221  28-Dec-22      8.76            1  55490  71882
# 96     9000     1496    152  13-Jul-22      8.30            1  21716   7403
# 97   150000     1999    147  18-Dec-15      0.74            3  42778  51890
# 98   126000     1560     88  15-Jul-16      2.31            2  24124  15774
# 99   120000     1598     90  25-Apr-16      2.01            1  19589  19589
#
#                                           accessories
# 0   Sport rims, leather seats, Pioneer head unit w...
# 1   Keyless entry, leather seats, factory fitted a...
# 2   Sport rims, leather upholstery, touch screen h...
# 3   Keyless Entry. Push Start/stop. Multi Steering...
# 4   Sunroof, leather seats, Pioneer audio system w...
# ..                                                ...
# 95  Apple CarPlay/Android Auto, Meridian sound sys...
# 96  Leather upholstery, Sport Rims, 9" Android med...
# 97  Carbon fibre exterior parts with the XES bodyk...
# 98  Consignment Unit, well taken care of by lady o...
# 99  Leather seats, sports rims, factory fitted aud...
#
# [100 rows x 12 columns]
# {'model_make_id': 'honda', 'model_name': 'Fit', 'model_trim': '', 'model_year': '2009', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1129', 'model_fuel_cap_l': '40'}
# {'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '1279', 'model_fuel_cap_l': '50'}
# {'model_make_id': 'toyota', 'model_name': 'Prius', 'model_trim': 'Plug-in', 'model_year': '2012', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline / Electric Hybrid', 'model_drive': 'Front', 'model_transmission_type': 'CVT', 'model_seats': '5', 'model_weight_kg': '1436', 'model_fuel_cap_l': '40'}
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# {'model_make_id': 'toyota', 'model_name': 'Corolla', 'model_trim': '', 'model_year': '2009', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Automatic', 'model_seats': '5', 'model_weight_kg': '1026', 'model_fuel_cap_l': '50'}
# {'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# {'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# Nothing found
# {'model_make_id': 'subaru', 'model_name': 'Legacy', 'model_trim': '2.0D Estate', 'model_year': '2009', 'model_body': 'Station Wagon', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'AWD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1558', 'model_fuel_cap_l': '65'}
# {'model_make_id': 'Volkswagen', 'model_name': 'Golf', 'model_trim': 'TDI S 4dr Hatchback (2.0L 4cyl Turbodiesel 6AM)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3126', 'model_fuel_cap_l': '13'}
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# {'model_make_id': 'Audi', 'model_name': 'A5', 'model_trim': '2.0T Premium Plus quattro 2dr Convertible AWD (2.0L 4cyl Turbo 8', 'model_year': '2018', 'model_body': 'Subcompact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4045', 'model_fuel_cap_l': '16'}
# {'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# {'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# {'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3274', 'model_fuel_cap_l': '13'}
# {'model_make_id': 'BMW', 'model_name': 'X3', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4030', 'model_fuel_cap_l': '18'}
# {'model_make_id': 'mazda', 'model_name': 'RX-8', 'model_trim': 'Challenge', 'model_year': '2008', 'model_body': 'Coupe', 'model_engine_cyl': None, 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Rear', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1425', 'model_fuel_cap_l': '61'}
# Nothing found
# {'model_make_id': 'Maserati', 'model_name': 'Ghibli', 'model_trim': '4dr Sedan (3.0L 6cyl Turbo 8A)', 'model_year': '2021', 'model_body': 'Large Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3992', 'model_fuel_cap_l': '21'}
# Nothing found
# {'model_make_id': 'toyota', 'model_name': 'Corolla', 'model_trim': '', 'model_year': '2010', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1235', 'model_fuel_cap_l': '50'}
# {'model_make_id': 'BMW', 'model_name': 'X5', 'model_trim': 'sDrive35i 4dr SUV (3.0L 6cyl Turbo 8A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# {'model_make_id': 'Kia', 'model_name': 'Sorento', 'model_trim': 'EX 4dr SUV (3.3L 6cyl 6A)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3722', 'model_fuel_cap_l': '17'}
# {'model_make_id': 'Mercedes-Benz', 'model_name': 'S-Class', 'model_trim': 'S550 4dr Sedan (4.7L 8cyl Turbo 7A)', 'model_year': '2020', 'model_body': 'Large Cars', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4630', 'model_fuel_cap_l': '21'}
# Nothing found
# Nothing found
# Nothing found
# {'model_make_id': 'Mercedes-Benz', 'model_name': 'GLA-Class', 'model_trim': 'GLA250 4dr SUV (2.0L 4cyl Turbo 7AM)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# {'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2022', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# Nothing found
# Nothing found
# {'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# {'model_make_id': 'toyota', 'model_name': 'Camry', 'model_trim': 'Hybrid', 'model_year': '2009', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline / Electric Hybrid', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1384', 'model_fuel_cap_l': '65'}
# Nothing found
# Nothing found
# {'model_make_id': 'Hyundai', 'model_name': 'Tucson', 'model_trim': 'GLS 4dr SUV (2.0L 4cyl 6A)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3232', 'model_fuel_cap_l': '15'}
# {'model_make_id': 'toyota', 'model_name': 'Corolla', 'model_trim': '', 'model_year': '2009', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Automatic', 'model_seats': '5', 'model_weight_kg': '1026', 'model_fuel_cap_l': '50'}
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# {'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# Nothing found
# {'model_make_id': 'MINI', 'model_name': 'Cooper', 'model_trim': '2dr Convertible (1.6L 4cyl 6M)', 'model_year': '2016', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2701', 'model_fuel_cap_l': '13'}
# {'model_make_id': 'Volvo', 'model_name': 'XC60', 'model_trim': '3.2 4dr SUV AWD w/Prod. End 6/14 (3.2L 6cyl 6A)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4251', 'model_fuel_cap_l': '19'}
# {'model_make_id': 'Audi', 'model_name': 'A5', 'model_trim': '2.0T Premium Plus quattro 2dr Convertible AWD (2.0L 4cyl Turbo 8', 'model_year': '2021', 'model_body': 'Subcompact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4045', 'model_fuel_cap_l': '16'}
# Nothing found
# Nothing found
# Nothing found
# {'model_make_id': 'porsche', 'model_name': 'Panamera', 'model_trim': '', 'model_year': '2011', 'model_body': 'Hatchback', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1760', 'model_fuel_cap_l': '100'}
# Nothing found
# {'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# Nothing found
# {'model_make_id': 'toyota', 'model_name': 'Corolla', 'model_trim': '', 'model_year': '2009', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Automatic', 'model_seats': '5', 'model_weight_kg': '1026', 'model_fuel_cap_l': '50'}
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# Nothing found
# {'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# {'model_make_id': 'mini', 'model_name': 'Cooper', 'model_trim': '', 'model_year': '2010', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1245', 'model_fuel_cap_l': '50'}
# Nothing found
# {'model_make_id': 'Porsche', 'model_name': 'Macan', 'model_trim': 'S 4dr SUV AWD (3.0L 6cyl Turbo 7AM)', 'model_year': '2022', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '4112', 'model_fuel_cap_l': '20'}
# Nothing found
# Nothing found
# {'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# Nothing found
# Nothing found
# {'model_make_id': 'Hyundai', 'model_name': 'Sonata', 'model_trim': 'Eco 4dr Sedan (1.6L 4cyl Turbo 7AM)', 'model_year': '2017', 'model_body': 'Large Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3270', 'model_fuel_cap_l': '19'}
# Nothing found
# {'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# Nothing found
# {'model_make_id': 'honda', 'model_name': 'Stream', 'model_trim': '1.7i ES', 'model_year': '2008', 'model_body': 'Minivan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '7', 'model_weight_kg': '1434', 'model_fuel_cap_l': '55'}
# Nothing found
# Nothing found
# {'model_make_id': 'Toyota', 'model_name': 'Prius', 'model_trim': 'Five 4dr Hatchback (1.8L 4cyl gas/electric hybrid CVT)', 'model_year': '2021', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3042', 'model_fuel_cap_l': '12'}
# Nothing found
# {'model_make_id': 'Jaguar', 'model_name': 'XF', 'model_trim': 'Portfolio 4dr Sedan (3.0L 6cyl S/C 8A)', 'model_year': '2015', 'model_body': 'Midsize Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3902', 'model_fuel_cap_l': '18'}
# Nothing found
# Nothing found
# Nothing found
# {'model_make_id': 'Honda', 'model_name': 'Fit', 'model_trim': 'EX 4dr Hatchback (1.5L 4cyl 6M)', 'model_year': '2022', 'model_body': 'Small Station Wagons', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2573', 'model_fuel_cap_l': '11'}
# Nothing found
# Nothing found
# {'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2016', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2820', 'model_fuel_cap_l': '13'}

# %%
data_filename = "../Dataset/merged_dataset.csv"

df = pd.read_csv(data_filename, nrows= 500, header= None)

column_names = ['name', 'price', 'depreciation', 'mileage', 'eng_cap', 'power', 'reg_date', 'coe_left', 'owners', ' omv', 'arf', 'accessories']
df.columns = column_names
res = []
counter = 0
for index, row in df.iterrows():
    info = extract_car_info(row['new_name'])
    if info == (None, None, None):
        counter += 1
        print(row)
    res.append(info)
print(counter)
print(res)
# Out:
# Name                    name
# Price                  price
# Depreciation    depreciation
# Mileage              mileage
# eng_cap              eng_cap
# power                  power
# reg_date            reg_date
# coe_left            coe_left
# owners                owners
#  omv                     omv
# arf                      arf
# accessories      accessories
# new_name            new_name
# Name: 0, dtype: object
# Name            BMW 7 Series Mild Hybrid 735i sDrive Pure Exce...
# Price                                                      537800
# Depreciation                                                50580
# Mileage                                                      3900
# eng_cap                                                      2998
# power                                                         213
# reg_date                                              20-Mar-2023
# coe_left                                                     8.99
# owners                                                          1
#  omv                                                       102460
# arf                                                        165412
# accessories     2023 BMW 735i Pure Excellence PGR ALED, 1 owne...
# new_name                                              Accessories
# Name: 223, dtype: object
# Name                            Toyota GR Yaris 1.6M Circuit Pack
# Price                                                      192888
# Depreciation                                                23940
# Mileage                                                     26000
# eng_cap                                                      1618
# power                                                         192
# reg_date                                              16-Apr-2021
# coe_left                                                     7.07
# owners                                                          3
#  omv                                                        39511
# arf                                                         47316
# accessories     Rocket Auto Trading. Borneo Motors unit. Legal...
# new_name                                              Accessories
# Name: 483, dtype: object
# 3
# [(None, None, None), ('Honda', 'Crossroad', '2008'), ('Subaru', 'Forester', '2013'), ('Honda', 'Shuttle Hybrid', '2015'), ('Toyota', 'Prius', None), ('Audi', 'Q2', '2017'), ('Mitsubishi', 'Outlander', '2014'), ('Volkswagen', 'Touran', '2016'), ('Porsche', 'Panamera', '2009'), ('Mercedes-Benz', 'E300', None), ('Honda', 'Odyssey', '2014'), ('BMW', '7 Series', '2009'), ('Audi', 'Q3', '2016'), ('Audi', 'S3 Sportback', '2009'), ('Maserati', 'GranTurismo', None), ('Mercedes-Benz', 'GLA-Class', '2014'), ('Renault', 'Megane GT', '2017'), ('Honda', 'Civic', '2016'), ('Subaru', 'XV', '2011'), ('Peugeot', '308 SW', '2015'), ('Nissan', 'Qashqai', '2014'), ('Mazda', 'CX-5', '2017'), ('Nissan', 'Elgrand', '2011'), ('Audi', 'Q5', '2009'), ('BMW', 'X1', '2015'), ('BMW', '318i', None), ('Honda', 'HR-V', '2015'), ('Mercedes-Benz', 'E-Class Saloon', '2009'), ('Audi', 'S3 Sportback', '2009'), ('Audi', 'S3 Sportback', '2009'), ('Audi', 'A4 Sedan', '2016'), ('Audi', 'Q3', '2019'), ('Mercedes-Benz', 'E250', None), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Toyota', 'Harrier', '2014'), ('Toyota', 'Camry', '2012'), ('Hyundai', 'Elantra', '2016'), ('Audi', 'A4 Sedan', '2016'), ('Mercedes-Benz', 'E-Class Coupe', '2009'), ('Mercedes-Benz', 'CLA-Class Shooting Brake', '2015'), ('Honda', 'Civic', '2016'), ('Mercedes-Benz', 'C-Class Saloon', '2014'), ('Honda', 'Odyssey', '2014'), ('Mercedes-Benz', 'GLC-Class Coupe Diesel', '2016'), ('BMW', '3 Series Sedan', '2012'), ('Infiniti', 'Q30', '2016'), ('Nissan', 'Latio Sedan', '2005'), ('Volkswagen', 'Golf', '2012'), ('Mercedes-Benz', 'C-Class Coupe', '2018'), ('MINI', 'Cooper S Roadster', '2012'), ('Mercedes-Benz', 'E-Class Saloon Plug-in Hybrid', '2021'), ('Porsche', 'Cayenne', '2010'), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Mercedes-Benz', 'E-Class Saloon', '2004'), ('Volkswagen', 'Scirocco', '2009'), ('Toyota', 'Harrier', None), ('Subaru', 'XV', '2017'), ('Mazda', '6 Sedan', '2013'), ('Kia', 'Cerato K3', '2013'), ('Kia', 'Sorento', '2015'), ('Mercedes-Benz', 'GLB-Class', '2020'), ('Honda', 'Shuttle', '2015'), ('BMW', '7 Series', '2009'), ('Audi', 'A4 Sedan', '2016'), ('Mercedes-Benz', 'CLA-Class', '2013'), ('BMW', 'X1', '2015'), ('Hyundai', 'i30', '2008'), ('Audi', 'A3 Sedan', '2014'), ('Volvo', 'XC40', '2018'), ('MINI', 'Cooper', None), ('Mercedes-Benz', 'GLA-Class', '2014'), ('SEAT', 'Ateca', '2017'), ('SKODA', 'Superb', '2018'), ('Mercedes-Benz', 'GLA-Class', '2014'), ('Subaru', 'Forester', '2013'), ('Bentley', 'Flying Spur', None), ('Honda', 'Odyssey', None), ('Honda', 'Fit', '2017'), ('Peugeot', '3008', '2017'), ('Volvo', 'S60', '2014'), ('McLaren', '720S', None), ('Lexus', 'IS 300', '2016'), ('Volvo', 'V40', '2013'), ('Toyota', 'Harrier', '2014'), ('Toyota', 'Harrier', '2014'), ('Nissan', 'Note', '2013'), ('Bentley', 'Continental', None), ('Nissan', 'Latio Sedan', '2005'), ('BMW', 'X5', '2019'), ('Audi', 'RS 5 Coupe', '2010'), ('Mercedes-Benz', 'B-Class', '2012'), ('Mercedes-Benz', 'C-Class Coupe Mild Hybrid', '2019'), ('Aston', 'Martin DB11', '2016'), ('Audi', 'A3 Sedan', '2014'), ('Honda', 'Fit', '2017'), ('Volvo', 'V40', '2013'), ('Kia', 'Cerato', '2018'), ('Mercedes-Benz', 'C-Class Saloon Mild Hybrid', '2022'), ('Hyundai', 'Elantra', '2016'), ('Mercedes-Benz', 'E-Class Coupe Mild Hybrid', '2019'), ('Honda', 'Freed Hybrid', '2016'), ('Rolls-Royce', 'Cullinan', None), ('Volkswagen', 'Golf', '2012'), ('Mercedes-Benz', 'GLB-Class', '2020'), ('Hyundai', 'Tucson', '2018'), ('Mercedes-Benz', 'S-Class', '2007'), ('Toyota', 'Sienta', '2016'), ('Audi', 'Q5', '2009'), ('Toyota', 'Camry', '2006'), ('Honda', 'Fit Shuttle', '2013'), ('Mazda', '2 Hatchback', '2015'), ('Volkswagen', 'Tiguan', '2008'), ('Porsche', 'Macan', '2014'), ('BMW', '2 Series Active Tourer', '2014'), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Volkswagen', 'Touran Sport', '2008'), ('Honda', 'HR-V', '2015'), ('Lexus', 'SC430', '2007'), ('Volkswagen', 'Golf', '2012'), ('Nissan', 'Qashqai', '2014'), ('Audi', 'R8', None), ('Volkswag ...

# %%
result_df = pd.concat([df, api_df], axis = 1)

output_filename = "combined_used_cars2.csv"

result_df.to_csv(output_filename, index = False)
