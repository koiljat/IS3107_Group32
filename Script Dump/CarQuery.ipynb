# %%
import requests
from tqdm import tqdm
import pandas as pd
import re
import os

# %% [markdown]
# # CarQuery

# %%
BASE_URL = 'https://www.carqueryapi.com/api/0.3'

header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}


def get_makes(year, sold_in_us=1):
    params = {
        'cmd': 'getMakes',
        'year': year,
        'sold_in_us': sold_in_us
    }
    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Makes']  # Adjust based on the actual key for makes

def get_models(make, year=None, sold_in_us=1, body=None):
    params = {
        'cmd': 'getModels',
        'make': make,
        'sold_in_us': sold_in_us
    }
    if year:
        params['year'] = year
    if body:
        params['body'] = body

    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Models']  # Adjust based on the actual key for models

def get_trims(make, model, year=None, trim=None, body=None):
    params = {
        'cmd': 'getTrims',
        'make': make,
        'model' : model
    }
    if year:
        params['year'] = year
    if trim:
        params['trim'] = trim
    if body:
        params['body'] = body

    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Trims']  # Adjust based on the actual key for trims

def get_model(model_id):
    params = {
        'cmd': 'getModel',
        'model': model_id
    }
    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()  # Adjust based on how the API returns data for a single model

def extract_car_info(car_string):
    pattern = re.compile(r'^(.*?)\s(.*?)(?:\s\((\d{4})-?\d*\)|\s(\d{4})|$)')
    match = pattern.search(car_string)
    if match:
        make = match.group(1)
        model = match.group(2)
        year = match.group(3) if match.group(3) else match.group(4)
        return make, model, year
    else:
        return None, None, None
    
def process_chunk(chunk):    
    # Set the columns that you want to keep from the API data
    api_columns = [
        'model_make_id', 'model_name', 'model_trim', 'model_year', 'model_body',
        'model_engine_cyl', 'model_engine_fuel', 'model_drive', 'model_transmission_type',
        'model_seats', 'model_weight_kg', 'model_fuel_cap_l'
    ]

    api_data = []

    # Process each row in the DataFrame
    for index, row in chunk.iterrows():
        try:
            name = row['model']
            reg_date = row['reg_date']

            name_split = name.split(' ')
            make = name_split[0]
            model = name_split[1]

            year = pd.to_datetime(reg_date).year if pd.notnull(reg_date) else None

            model_info = get_trims(make=make, model=model, year= year)

            if model_info:
                first_trim = model_info[0]  # Safely get the first trim
                # Select only the desired columns
                selected_trim_info = {key: first_trim.get(key, pd.NA) for key in api_columns}
                print(str(index) + str(selected_trim_info))
                api_data.append(selected_trim_info)
            else:
                print(str(index) + " Nothing found")
                placeholder = {key: pd.NA for key in api_columns}
                api_data.append(placeholder)
        except Exception as e:
            print(f"Error processing row {index }:{ e}")
            break

    result_df = pd.concat([chunk, pd.DataFrame(api_data)], axis = 1)
    
    return result_df

# %% [markdown]
# # Loading the data

# %%
data_filename = "../Datasets/merged_dataset.csv"
start_row = 3400 
chunk_size = 2500

chunk = pd.read_csv(data_filename, skiprows= range(1,start_row + 1), nrows=chunk_size, header=0)

# print(chunk)
api_df = process_chunk(chunk)

output_filename = '../Datasets/CarQuery.csv'

# Check if the file exists and has content
if os.path.exists(output_filename) and os.path.getsize(output_filename) > 0:
    header = False  # Don't write header if file already exists
else:
    header = True  # Write header if file doesn't exist

# Append or write the DataFrame to the CSV file
api_df.to_csv(output_filename, mode='a', index=False, header=header)
# Out:
# 0 Nothing found
# 1 Nothing found
# 2 Nothing found
# 3{'model_make_id': 'Honda', 'model_name': 'Fit', 'model_trim': 'EX 4dr Hatchback (1.5L 4cyl 6M)', 'model_year': '2020', 'model_body': 'Small Station Wagons', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2573', 'model_fuel_cap_l': '11'}
# 4 Nothing found
# 5{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 6{'model_make_id': 'toyota', 'model_name': 'Camry', 'model_trim': 'Hybrid', 'model_year': '2009', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline / Electric Hybrid', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1384', 'model_fuel_cap_l': '65'}
# 7{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2020', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 8 Nothing found
# 9 Nothing found
# 10{'model_make_id': 'Toyota', 'model_name': 'Camry', 'model_trim': 'LE 4dr Sedan (2.5L 4cyl 6A)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3240', 'model_fuel_cap_l': '17'}
# 11{'model_make_id': 'honda', 'model_name': 'Civic', 'model_trim': '1.3i-DSi Vtec Hybrid', 'model_year': '2009', 'model_body': 'Sedan', 'model_engine_cyl': None, 'model_engine_fuel': 'Gasoline / Electric Hybrid', 'model_drive': 'Front', 'model_transmission_type': None, 'model_seats': '5', 'model_weight_kg': '1368', 'model_fuel_cap_l': '50'}
# 12 Nothing found
# 13 Nothing found
# 14 Nothing found
# 15{'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# 16{'model_make_id': 'Honda', 'model_name': 'Odyssey', 'model_trim': 'EX 4dr Minivan (3.5L 6cyl 6A)', 'model_year': '2017', 'model_body': 'Minivan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4470', 'model_fuel_cap_l': '21'}
# 17{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 18 Nothing found
# 19 Nothing found
# 20{'model_make_id': 'Honda', 'model_name': 'Accord', 'model_trim': 'EX 2dr Coupe (2.4L 4cyl 6M)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3229', 'model_fuel_cap_l': '17'}
# 21 Nothing found
# 22 Nothing found
# 23{'model_make_id': 'subaru', 'model_name': 'Impreza', 'model_trim': '2.5GT', 'model_year': '2010', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'AWD', 'model_transmission_type': 'Automatic', 'model_seats': '5', 'model_weight_kg': '1470', 'model_fuel_cap_l': '64'}
# 24 Nothing found
# 25{'model_make_id': 'Volkswagen', 'model_name': 'Golf', 'model_trim': '2.5L PZEV 4dr Hatchback (2.5L 5cyl 6A)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '5', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '1407', 'model_fuel_cap_l': '55'}
# 26 Nothing found
# 27{'model_make_id': 'Volkswagen', 'model_name': 'Golf', 'model_trim': 'TDI S 4dr Hatchback (2.0L 4cyl Turbodiesel 6AM)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3126', 'model_fuel_cap_l': '13'}
# 28 Nothing found
# 29 Nothing found
# 30 Nothing found
# 31 Nothing found
# 32 Nothing found
# 33{'model_make_id': 'mazda', 'model_name': '3', 'model_trim': '1.6', 'model_year': '2010', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': '5-speed manual', 'model_seats': '5', 'model_weight_kg': None, 'model_fuel_cap_l': '55'}
# 34{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 35{'model_make_id': 'Mercedes-Benz', 'model_name': 'GLA-Class', 'model_trim': 'GLA250 4dr SUV (2.0L 4cyl Turbo 7AM)', 'model_year': '2020', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 36{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 37 Nothing found
# 38 Nothing found
# 39 Nothing found
# 40 Nothing found
# 41 Nothing found
# 42 Nothing found
# 43 Nothing found
# 44 Nothing found
# 45{'model_make_id': 'Hyundai', 'model_name': 'Sonata', 'model_trim': 'Eco 4dr Sedan (1.6L 4cyl Turbo 7AM)', 'model_year': '2016', 'model_body': 'Large Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3270', 'model_fuel_cap_l': '19'}
# 46 Nothing found
# 47 Nothing found
# 48 Nothing found
# 49{'model_make_id': 'Volvo', 'model_name': 'S80', 'model_trim': 'T5 Drive-E 4dr Sedan (2.0L 4cyl Turbo 8A)', 'model_year': '2016', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '19'}
# 50{'model_make_id': 'MINI', 'model_name': 'Cooper', 'model_trim': '2dr Convertible (1.6L 4cyl 6M)', 'model_year': '2017', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2701', 'model_fuel_cap_l': '13'}
# 51 Nothing found
# 52 Nothing found
# 53{'model_make_id': 'Jaguar', 'model_name': 'XJ', 'model_trim': '4dr Sedan (3.0L 6cyl S/C 8A)', 'model_year': '2019', 'model_body': 'Large Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Flex-Fuel (Premium Unleaded Requ', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3854', 'model_fuel_cap_l': '22'}
# 54{'model_make_id': 'porsche', 'model_name': 'Cayenne', 'model_trim': '', 'model_year': '2011', 'model_body': 'SUV', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1995', 'model_fuel_cap_l': '85'}
# 55{'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3274', 'model_fuel_cap_l': '13'}
# 56 Nothing found
# 57{'model_make_id': 'Infiniti', 'model_name': 'Q50', 'model_trim': '4dr Sedan (3.7L 6cyl 7A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '20'}
# 58 Nothing found
# 59{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 60 Nothing found
# 61 Nothing found
# 62{'model_make_id': 'Mercedes-Benz', 'model_name': 'GLA-Class', 'model_trim': 'GLA250 4dr SUV (2.0L 4cyl Turbo 7AM)', 'model_year': '2022', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 63 Nothing found
# 64 Nothing found
# 65{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 66{'model_make_id': 'Mitsubishi', 'model_name': 'Outlander', 'model_trim': 'ES 4dr SUV (2.4L 4cyl CVT)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3285', 'model_fuel_cap_l': '17'}
# 67 Nothing found
# 68 Nothing found
# 69{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 70 Nothing found
# 71 Nothing found
# 72 Nothing found
# 73 Nothing found
# 74 Nothing found
# 75{'model_make_id': 'volkswagen', 'model_name': 'Golf', 'model_trim': '1.2 TSI 3 Door', 'model_year': '2011', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': '6-speed manual', 'model_seats': '5', 'model_weight_kg': '1229', 'model_fuel_cap_l': '55'}
# 76{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 77 Nothing found
# 78 Nothing found
# 79 Nothing found
# 80{'model_make_id': 'Jaguar', 'model_name': 'XF', 'model_trim': 'Portfolio 4dr Sedan (3.0L 6cyl S/C 8A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3902', 'model_fuel_cap_l': '18'}
# 81 Nothing found
# 82{'model_make_id': 'Toyota', 'model_name': 'Prius', 'model_trim': 'Five 4dr Hatchback (1.8L 4cyl gas/electric hybrid CVT)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3042', 'model_fuel_cap_l': '12'}
# 83 Nothing found
# 84 Nothing found
# 85 Nothing found
# 86{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 87 Nothing found
# 88 Nothing found
# 89{'model_make_id': 'Honda', 'model_name': 'CR-V', 'model_trim': 'EX 4dr SUV (2.4L 4cyl CVT)', 'model_year': '2016', 'model_body': 'Small Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3437', 'model_fuel_cap_l': '15'}
# 90 Nothing found
# 91{'model_make_id': 'Audi', 'model_name': 'A5', 'model_trim': '2.0T Premium Plus quattro 2dr Convertible AWD (2.0L 4cyl Turbo 8', 'model_year': '2017', 'model_body': 'Subcompact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4045', 'model_fuel_cap_l': '16'}
# 92{'model_make_id': 'maserati', 'model_name': 'GranTurismo', 'model_trim': '', 'model_year': '2012', 'model_body': 'Coupe', 'model_engine_cyl': '8', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Automatic', 'model_seats': '4', 'model_weight_kg': '1881', 'model_fuel_cap_l': '86'}
# 93 Nothing found
# 94 Nothing found
# 95{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2022', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 96 Nothing found
# 97 Nothing found
# 98{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 99 Nothing found
# 100 Nothing found
# 101 Nothing found
# 102 Nothing found
# 103 Nothing found
# 104 Nothing found
# 105{'model_make_id': 'Toyota', 'model_name': 'Prius', 'model_trim': 'Five 4dr Hatchback (1.8L 4cyl gas/electric hybrid CVT)', 'model_year': '2020', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3042', 'model_fuel_cap_l': '12'}
# 106{'model_make_id': 'Porsche', 'model_name': 'Macan', 'model_trim': 'S 4dr SUV AWD (3.0L 6cyl Turbo 7AM)', 'model_year': '2022', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '4112', 'model_fuel_cap_l': '20'}
# 107{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 108 Nothing found
# 109 Nothing found
# 110 Nothing found
# 111 Nothing found
# 112 Nothing found
# 113{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 114 Nothing found
# 115 Nothing found
# 116 Nothing found
# 117{'model_make_id': 'Volvo', 'model_name': 'XC60', 'model_trim': '3.2 4dr SUV AWD w/Prod. End 6/14 (3.2L 6cyl 6A)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4251', 'model_fuel_cap_l': '19'}
# 118 Nothing found
# 119 Nothing found
# 120 Nothing found
# 121 Nothing found
# 122 Nothing found
# 123 Nothing found
# 124 Nothing found
# 125{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 126 Nothing found
# 127{'model_make_id': 'Volvo', 'model_name': 'XC60', 'model_trim': '3.2 4dr SUV AWD w/Prod. End 6/14 (3.2L 6cyl 6A)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4251', 'model_fuel_cap_l': '19'}
# 128 Nothing found
# 129 Nothing found
# 130 Nothing found
# 131{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 132{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2021', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 133 Nothing found
# 134{'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# 135{'model_make_id': 'Kia', 'model_name': 'Sorento', 'model_trim': 'EX 4dr SUV (3.3L 6cyl 6A)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3722', 'model_fuel_cap_l': '17'}
# 136 Nothing found
# 137{'model_make_id': 'Hyundai', 'model_name': 'Tucson', 'model_trim': 'GLS 4dr SUV (2.0L 4cyl 6A)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3232', 'model_fuel_cap_l': '15'}
# 138{'model_make_id': 'Hyundai', 'model_name': 'Accent', 'model_trim': 'GLS 4dr Sedan (1.6L 4cyl 6A)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2546', 'model_fuel_cap_l': '11'}
# 139{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2021', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 140{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 141{'model_make_id': 'Audi', 'model_name': 'A5', 'model_trim': '2.0T Premium Plus quattro 2dr Convertible AWD (2.0L 4cyl Turbo 8', 'model_year': '2021', 'model_body': 'Subcompact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4045', 'model_fuel_cap_l': '16'}
# 142 Nothing found
# 143 Nothing found
# 144 Nothing found
# 145{'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '1279', 'model_fuel_cap_l': '50'}
# 146 Nothing found
# 147{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 148 Nothing found
# 149 Nothing found
# 150 Nothing found
# 151{'model_make_id': 'Mercedes-Benz', 'model_name': 'S-Class', 'model_trim': 'S550 4dr Sedan (4.7L 8cyl Turbo 7A)', 'model_year': '2016', 'model_body': 'Large Cars', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4630', 'model_fuel_cap_l': '21'}
# 152{'model_make_id': 'porsche', 'model_name': 'Cayenne', 'model_trim': '', 'model_year': '2011', 'model_body': 'SUV', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1995', 'model_fuel_cap_l': '85'}
# 153{'model_make_id': 'Honda', 'model_name': 'Odyssey', 'model_trim': 'EX 4dr Minivan (3.5L 6cyl 6A)', 'model_year': '2016', 'model_body': 'Minivan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4470', 'model_fuel_cap_l': '21'}
# 154{'model_make_id': 'toyota', 'model_name': 'Corolla', 'model_trim': '1.6 VVT-i', 'model_year': '2008', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': None, 'model_seats': '5', 'model_weight_kg': '1194', 'model_fuel_cap_l': '55'}
# 155{'model_make_id': 'Volvo', 'model_name': 'S60', 'model_trim': 'T5 4dr Sedan AWD (2.5L 5cyl Turbo 6A)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '5', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3528', 'model_fuel_cap_l': '18'}
# 156{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 157{'model_make_id': 'volkswagen', 'model_name': 'Scirocco', 'model_trim': '1.4 Supercharged', 'model_year': '2010', 'model_body': 'Hatchback', 'model_engine_cyl': None, 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1298', 'model_fuel_cap_l': None}
# 158{'model_make_id': 'volkswagen', 'model_name': 'Golf', 'model_trim': '1.2 TSI 3 Door', 'model_year': '2012', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': '6-speed manual', 'model_seats': '5', 'model_weight_kg': '1229', 'model_fuel_cap_l': '55'}
# 159 Nothing found
# 160 Nothing found
# 161{'model_make_id': 'mitsubishi', 'model_name': 'Lancer', 'model_trim': '1.3', 'model_year': '2007', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1200', 'model_fuel_cap_l': '50'}
# 162{'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '1480', 'model_fuel_cap_l': '50'}
# 163{'model_make_id': 'Mercedes-Benz', 'model_name': 'GLA-Class', 'model_trim': 'GLA250 4dr SUV (2.0L 4cyl Turbo 7AM)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 164{'model_make_id': 'Toyota', 'model_name': 'RAV4', 'model_trim': 'LE 4dr SUV (2.5L 4cyl 6A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3435', 'model_fuel_cap_l': '16'}
# 165{'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# 166 Nothing found
# 167 Nothing found
# 168{'model_make_id': 'Mitsubishi', 'model_name': 'Lancer', 'model_trim': 'ES 4dr Sedan (2.0L 4cyl 5M)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2888', 'model_fuel_cap_l': '16'}
# 169{'model_make_id': 'ferrari', 'model_name': 'California', 'model_trim': '', 'model_year': '2010', 'model_body': 'Convertible', 'model_engine_cyl': '8', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1735', 'model_fuel_cap_l': '78'}
# 170{'model_make_id': 'ferrari', 'model_name': 'California', 'model_trim': '', 'model_year': '2010', 'model_body': 'Convertible', 'model_engine_cyl': '8', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1735', 'model_fuel_cap_l': '78'}
# 171 Nothing found
# 172 Nothing found
# 173 Nothing found
# 174{'model_make_id': 'Porsche', 'model_name': 'Macan', 'model_trim': 'S 4dr SUV AWD (3.0L 6cyl Turbo 7AM)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '4112', 'model_fuel_cap_l': '20'}
# 175{'model_make_id': 'Audi', 'model_name': 'TT', 'model_trim': '2.0T quattro 2dr Convertible AWD (2.0L 4cyl Turbo 6AM)', 'model_year': '2022', 'model_body': 'Two Seaters', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3340', 'model_fuel_cap_l': '16'}
# 176{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '1605', 'model_fuel_cap_l': '66'}
# 177{'model_make_id': 'Volkswagen', 'model_name': 'Golf', 'model_trim': '2dr Hatchback (1.8L 4cyl Turbo 5M)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '1246', 'model_fuel_cap_l': '55'}
# 178 Nothing found
# 179 Nothing found
# 180 Nothing found
# 181 Nothing found
# 182{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 183 Nothing found
# 184 Nothing found
# 185 Nothing found
# 186 Nothing found
# 187{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 188 Nothing found
# 189{'model_make_id': 'audi', 'model_name': 'S5', 'model_trim': '3.0T Premium Plus Quattro', 'model_year': '2010', 'model_body': 'Coupe', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': 'AWD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1955', 'model_fuel_cap_l': '64'}
# 190{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 191{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 192{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 193 Nothing found
# 194{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 195 Nothing found
# 196{'model_make_id': 'suzuki', 'model_name': 'SX4', 'model_trim': '2', 'model_year': '2009', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1295', 'model_fuel_cap_l': '50'}
# 197 Nothing found
# 198 Nothing found
# 199 Nothing found
# 200 Nothing found
# 201{'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2021', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# 202 Nothing found
# 203 Nothing found
# 204 Nothing found
# 205 Nothing found
# 206{'model_make_id': 'audi', 'model_name': 'R8', 'model_trim': '4.2 Quattro', 'model_year': '2012', 'model_body': 'Coupe', 'model_engine_cyl': '8', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'AWD', 'model_transmission_type': '6-speed manual', 'model_seats': '2', 'model_weight_kg': '1635', 'model_fuel_cap_l': '90'}
# 207{'model_make_id': 'hyundai', 'model_name': 'i30', 'model_trim': '1.6', 'model_year': '2008', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': None, 'model_seats': '5', 'model_weight_kg': '1214', 'model_fuel_cap_l': '53'}
# 208 Nothing found
# 209 Nothing found
# 210{'model_make_id': 'Volkswagen', 'model_name': 'Tiguan', 'model_trim': 'R-Line 4dr SUV (2.0L 4cyl Turbo 6A)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3404', 'model_fuel_cap_l': '17'}
# 211 Nothing found
# 212 Nothing found
# 213 Nothing found
# 214 Nothing found
# 215{'model_make_id': 'Honda', 'model_name': 'Accord', 'model_trim': 'EX 2dr Coupe (2.4L 4cyl 6M)', 'model_year': '2022', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3229', 'model_fuel_cap_l': '17'}
# 216 Nothing found
# 217{'model_make_id': 'porsche', 'model_name': '911', 'model_trim': 'Cabriolet 4s', 'model_year': '2009', 'model_body': 'Convertible', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': None, 'model_fuel_cap_l': '67'}
# 218{'model_make_id': 'Mercedes-Benz', 'model_name': 'G-Class', 'model_trim': 'G550 4dr SUV 4WD (5.5L 8cyl 7A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Four Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '5578', 'model_fuel_cap_l': '25'}
# 219{'model_make_id': 'Volkswagen', 'model_name': 'Beetle', 'model_trim': '1.8T 2dr Hatchback (1.8L 4cyl Turbo 5M)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2948', 'model_fuel_cap_l': '15'}
# 220{'model_make_id': 'Hyundai', 'model_name': 'Elantra', 'model_trim': 'Limited 4dr Sedan (1.8L 4cyl 6A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2818', 'model_fuel_cap_l': '13'}
# 221{'model_make_id': 'porsche', 'model_name': '911', 'model_trim': 'Cabriolet', 'model_year': '2008', 'model_body': 'Convertible', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': 'Automatic', 'model_seats': '4', 'model_weight_kg': None, 'model_fuel_cap_l': '67'}
# 222{'model_make_id': 'rolls-royce', 'model_name': 'Ghost', 'model_trim': '', 'model_year': '2011', 'model_body': 'Sedan', 'model_engine_cyl': '12', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Automatic', 'model_seats': '5', 'model_weight_kg': '2490', 'model_fuel_cap_l': '83'}
# 223{'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '1480', 'model_fuel_cap_l': '50'}
# 224 Nothing found
# 225 Nothing found
# 226 Nothing found
# 227{'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3274', 'model_fuel_cap_l': '13'}
# 228{'model_make_id': 'audi', 'model_name': 'TT', 'model_trim': '2.0T FSi Roadster', 'model_year': '2009', 'model_body': 'Convertible', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '2', 'model_weight_kg': '895', 'model_fuel_cap_l': '55'}
# 229{'model_make_id': 'Porsche', 'model_name': 'Cayman', 'model_trim': '2dr Coupe (2.7L 6cyl 6M)', 'model_year': '2014', 'model_body': 'Two Seaters', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '1310', 'model_fuel_cap_l': '64'}
# 230{'model_make_id': 'Honda', 'model_name': 'Odyssey', 'model_trim': 'EX 4dr Minivan (3.5L 6cyl 6A)', 'model_year': '2019', 'model_body': 'Minivan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4470', 'model_fuel_cap_l': '21'}
# 231 Nothing found
# 232{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2019', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 233 Nothing found
# 234 Nothing found
# 235 Nothing found
# 236 Nothing found
# 237 Nothing found
# 238{'model_make_id': 'Honda', 'model_name': 'Accord', 'model_trim': 'EX 2dr Coupe (2.4L 4cyl 6M)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3229', 'model_fuel_cap_l': '17'}
# 239{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 240{'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# 241{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2016', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 242 Nothing found
# 243{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2021', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 244{'model_make_id': 'Mercedes-Benz', 'model_name': 'GLA-Class', 'model_trim': 'GLA250 4dr SUV (2.0L 4cyl Turbo 7AM)', 'model_year': '2015', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 245 Nothing found
# 246{'model_make_id': 'Kia', 'model_name': 'Sportage', 'model_trim': 'EX 4dr SUV (2.4L 4cyl 6A)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 247{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 248 Nothing found
# 249 Nothing found
# 250{'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2022', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# 251 Nothing found
# 252{'model_make_id': 'Hyundai', 'model_name': 'Accent', 'model_trim': 'GLS 4dr Sedan (1.6L 4cyl 6A)', 'model_year': '2020', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2546', 'model_fuel_cap_l': '11'}
# 253{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 254 Nothing found
# 255 Nothing found
# 256 Nothing found
# 257 Nothing found
# 258{'model_make_id': 'volkswagen', 'model_name': 'Scirocco', 'model_trim': '1.4 Supercharged', 'model_year': '2010', 'model_body': 'Hatchback', 'model_engine_cyl': None, 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1298', 'model_fuel_cap_l': None}
# 259{'model_make_id': 'BMW', 'model_name': 'X5', 'model_trim': 'sDrive35i 4dr SUV (3.0L 6cyl Turbo 8A)', 'model_year': '2015', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 260 Nothing found
# 261{'model_make_id': 'mini', 'model_name': 'Cooper', 'model_trim': '', 'model_year': '2010', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1245', 'model_fuel_cap_l': '50'}
# 262{'model_make_id': 'Volkswagen', 'model_name': 'Golf', 'model_trim': 'TDI S 4dr Hatchback (2.0L 4cyl Turbodiesel 6AM)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3126', 'model_fuel_cap_l': '13'}
# 263 Nothing found
# 264 Nothing found
# 265{'model_make_id': 'Hyundai', 'model_name': 'Accent', 'model_trim': 'GLS 4dr Sedan (1.6L 4cyl 6A)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2546', 'model_fuel_cap_l': '11'}
# 266 Nothing found
# 267{'model_make_id': 'Toyota', 'model_name': 'Camry', 'model_trim': 'LE 4dr Sedan (2.5L 4cyl 6A)', 'model_year': '2019', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3240', 'model_fuel_cap_l': '17'}
# 268{'model_make_id': 'bentley', 'model_name': 'Continental', 'model_trim': ' Supersports', 'model_year': '2013', 'model_body': 'Coupe', 'model_engine_cyl': '12', 'model_engine_fuel': 'Premium', 'model_drive': 'AWD ', 'model_transmission_type': '6-speed automatic', 'model_seats': '4', 'model_weight_kg': '2395', 'model_fuel_cap_l': '90'}
# 269 Nothing found
# 270 Nothing found
# 271{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2022', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 272 Nothing found
# 273 Nothing found
# 274 Nothing found
# 275 Nothing found
# 276 Nothing found
# 277 Nothing found
# 278 Nothing found
# 279 Nothing found
# 280 Nothing found
# ...
# 1995{'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2820', 'model_fuel_cap_l': '13'}
# 1996 Nothing found
# 1997 Nothing found
# 1998{'model_make_id': 'Jaguar', 'model_name': 'XF', 'model_trim': 'Portfolio 4dr Sedan (3.0L 6cyl S/C 8A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3902', 'model_fuel_cap_l': '18'}
# 1999 Nothing found
# 2000 Nothing found
# 2001 Nothing found
# 2002{'model_make_id': 'suzuki', 'model_name': 'Swift', 'model_trim': '1.4', 'model_year': '2010', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 2003 Nothing found
# 2004 Nothing found
# 2005 Nothing found
# 2006 Nothing found
# 2007 Nothing found
# 2008{'model_make_id': 'Volvo', 'model_name': 'S60', 'model_trim': 'T5 4dr Sedan AWD (2.5L 5cyl Turbo 6A)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '5', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3528', 'model_fuel_cap_l': '18'}
# 2009 Nothing found
# 2010 Nothing found
# 2011{'model_make_id': 'Audi', 'model_name': 'A6', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2016', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3726', 'model_fuel_cap_l': '20'}
# 2012 Nothing found
# 2013 Nothing found
# 2014{'model_make_id': 'Volkswagen', 'model_name': 'Golf', 'model_trim': 'TDI S 4dr Hatchback (2.0L 4cyl Turbodiesel 6AM)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3126', 'model_fuel_cap_l': '13'}
# 2015 Nothing found
# 2016 Nothing found
# 2017{'model_make_id': 'Chevrolet', 'model_name': 'Cruze', 'model_trim': '1LT 4dr Sedan (1.4L 4cyl Turbo 6A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3118', 'model_fuel_cap_l': '16'}
# 2018{'model_make_id': 'honda', 'model_name': 'Integra', 'model_trim': '', 'model_year': '2006', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': None, 'model_fuel_cap_l': '50'}
# 2019{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 2020{'model_make_id': 'BMW', 'model_name': 'M6', 'model_trim': '2dr Convertible (4.4L 8cyl Turbo 7AM)', 'model_year': '2014', 'model_body': 'Subcompact Cars', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '2045', 'model_fuel_cap_l': '80'}
# 2021 Nothing found
# 2022 Nothing found
# 2023 Nothing found
# 2024 Nothing found
# 2025 Nothing found
# 2026 Nothing found
# 2027 Nothing found
# 2028 Nothing found
# 2029 Nothing found
# 2030{'model_make_id': 'porsche', 'model_name': 'Boxster', 'model_trim': '', 'model_year': '2009', 'model_body': 'Convertible', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Manual', 'model_seats': '2', 'model_weight_kg': None, 'model_fuel_cap_l': '64'}
# 2031 Nothing found
# 2032{'model_make_id': 'Honda', 'model_name': 'Fit', 'model_trim': 'EX 4dr Hatchback (1.5L 4cyl 6M)', 'model_year': '2022', 'model_body': 'Small Station Wagons', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2573', 'model_fuel_cap_l': '11'}
# 2033 Nothing found
# 2034 Nothing found
# 2035{'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2022', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2820', 'model_fuel_cap_l': '13'}
# 2036{'model_make_id': 'Jaguar', 'model_name': 'XF', 'model_trim': 'Portfolio 4dr Sedan (3.0L 6cyl S/C 8A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3902', 'model_fuel_cap_l': '18'}
# 2037{'model_make_id': 'Volkswagen', 'model_name': 'Passat', 'model_trim': 'S 4dr Sedan (1.8L 4cyl Turbo 5M)', 'model_year': '2019', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3172', 'model_fuel_cap_l': '19'}
# 2038{'model_make_id': 'Volkswagen', 'model_name': 'Beetle', 'model_trim': '1.8T 2dr Hatchback (1.8L 4cyl Turbo 5M)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2948', 'model_fuel_cap_l': '15'}
# 2039 Nothing found
# 2040{'model_make_id': 'mini', 'model_name': 'Cooper', 'model_trim': '', 'model_year': '2012', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': '6-speed manual', 'model_seats': '4', 'model_weight_kg': '1225', 'model_fuel_cap_l': '50'}
# 2041 Nothing found
# 2042 Nothing found
# 2043 Nothing found
# 2044 Nothing found
# 2045 Nothing found
# 2046{'model_make_id': 'Audi', 'model_name': 'Q3', 'model_trim': 'Premium Plus 4dr SUV (2.0L 4cyl Turbo 6A)', 'model_year': '2021', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3494', 'model_fuel_cap_l': '17'}
# 2047{'model_make_id': 'Hyundai', 'model_name': 'Elantra', 'model_trim': 'Limited 4dr Sedan (1.8L 4cyl 6A)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2818', 'model_fuel_cap_l': '13'}
# 2048 Nothing found
# 2049 Nothing found
# 2050 Nothing found
# 2051 Nothing found
# 2052 Nothing found
# 2053 Nothing found
# 2054{'model_make_id': 'volkswagen', 'model_name': 'Beetle', 'model_trim': '', 'model_year': '2012', 'model_body': 'Coupe', 'model_engine_cyl': '5', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': '5-speed manual', 'model_seats': '5', 'model_weight_kg': '1333', 'model_fuel_cap_l': '55'}
# 2055 Nothing found
# 2056{'model_make_id': 'porsche', 'model_name': 'Cayenne', 'model_trim': '', 'model_year': '2012', 'model_body': 'SUV', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': '6-speed manual', 'model_seats': '5', 'model_weight_kg': '1995', 'model_fuel_cap_l': '85'}
# 2057 Nothing found
# 2058 Nothing found
# 2059 Nothing found
# 2060 Nothing found
# 2061 Nothing found
# 2062 Nothing found
# 2063{'model_make_id': 'MINI', 'model_name': 'Cooper', 'model_trim': '2dr Convertible (1.6L 4cyl 6M)', 'model_year': '2016', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2701', 'model_fuel_cap_l': '13'}
# 2064 Nothing found
# 2065 Nothing found
# 2066{'model_make_id': 'honda', 'model_name': 'Civic', 'model_trim': '1.4', 'model_year': '2007', 'model_body': None, 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1240', 'model_fuel_cap_l': '50'}
# 2067 Nothing found
# 2068 Nothing found
# 2069 Nothing found
# 2070 Nothing found
# 2071{'model_make_id': 'Volkswagen', 'model_name': 'Beetle', 'model_trim': '1.8T 2dr Hatchback (1.8L 4cyl Turbo 5M)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2948', 'model_fuel_cap_l': '15'}
# 2072 Nothing found
# 2073 Nothing found
# 2074 Nothing found
# 2075 Nothing found
# 2076 Nothing found
# 2077 Nothing found
# 2078 Nothing found
# 2079{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 2080{'model_make_id': 'Volkswagen', 'model_name': 'Passat', 'model_trim': 'S 4dr Sedan (1.8L 4cyl Turbo 5M)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3172', 'model_fuel_cap_l': '19'}
# 2081 Nothing found
# 2082 Nothing found
# 2083 Nothing found
# 2084{'model_make_id': 'Volkswagen', 'model_name': 'Passat', 'model_trim': 'S 4dr Sedan (1.8L 4cyl Turbo 5M)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3172', 'model_fuel_cap_l': '19'}
# 2085{'model_make_id': 'Maserati', 'model_name': 'Quattroporte', 'model_trim': 'GTS 4dr Sedan (3.8L 8cyl Turbo 8A)', 'model_year': '2020', 'model_body': 'Large Cars', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4191', 'model_fuel_cap_l': '21'}
# 2086{'model_make_id': 'BMW', 'model_name': 'X5', 'model_trim': 'sDrive35i 4dr SUV (3.0L 6cyl Turbo 8A)', 'model_year': '2022', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 2087{'model_make_id': 'Honda', 'model_name': 'Odyssey', 'model_trim': 'EX 4dr Minivan (3.5L 6cyl 6A)', 'model_year': '2016', 'model_body': 'Minivan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4470', 'model_fuel_cap_l': '21'}
# 2088 Nothing found
# 2089 Nothing found
# 2090{'model_make_id': 'volkswagen', 'model_name': 'Tiguan', 'model_trim': 'S', 'model_year': '2010', 'model_body': 'SUV', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1557', 'model_fuel_cap_l': '64'}
# 2091 Nothing found
# 2092 Nothing found
# 2093 Nothing found
# 2094 Nothing found
# 2095 Nothing found
# 2096 Nothing found
# 2097 Nothing found
# 2098 Nothing found
# 2099{'model_make_id': 'Infiniti', 'model_name': 'Q50', 'model_trim': '4dr Sedan (3.7L 6cyl 7A)', 'model_year': '2016', 'model_body': 'Midsize Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '20'}
# 2100 Nothing found
# 2101{'model_make_id': 'Porsche', 'model_name': 'Cayenne', 'model_trim': 'Diesel 4dr SUV AWD (3.0L 6cyl Turbodiesel 8A)', 'model_year': '2021', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Diesel', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4652', 'model_fuel_cap_l': '26'}
# 2102 Nothing found
# 2103 Nothing found
# 2104 Nothing found
# 2105 Nothing found
# 2106{'model_make_id': 'Porsche', 'model_name': '911', 'model_trim': 'Carrera 2dr Convertible (3.4L 6cyl 7M)', 'model_year': '2018', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3197', 'model_fuel_cap_l': '17'}
# 2107 Nothing found
# 2108 Nothing found
# 2109{'model_make_id': 'Volkswagen', 'model_name': 'Jetta', 'model_trim': '4dr Sedan (2.0L 4cyl 5M)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2859', 'model_fuel_cap_l': '15'}
# 2110{'model_make_id': 'subaru', 'model_name': 'Legacy', 'model_trim': '2.0D Estate', 'model_year': '2009', 'model_body': 'Station Wagon', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'AWD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1558', 'model_fuel_cap_l': '65'}
# 2111 Nothing found
# 2112{'model_make_id': 'Porsche', 'model_name': 'Macan', 'model_trim': 'S 4dr SUV AWD (3.0L 6cyl Turbo 7AM)', 'model_year': '2015', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '4112', 'model_fuel_cap_l': '20'}
# 2113 Nothing found
# 2114 Nothing found
# 2115 Nothing found
# 2116 Nothing found
# 2117{'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2820', 'model_fuel_cap_l': '13'}
# 2118{'model_make_id': 'Volkswagen', 'model_name': 'Beetle', 'model_trim': '1.8T 2dr Hatchback (1.8L 4cyl Turbo 5M)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2948', 'model_fuel_cap_l': '15'}
# 2119 Nothing found
# Error processing row 2120:'Trims'

# %%
data_filename = "../Dataset/merged_dataset.csv"

df = pd.read_csv(data_filename, nrows= 500, header= None)

column_names = ['name', 'price', 'depreciation', 'mileage', 'eng_cap', 'power', 'reg_date', 'coe_left', 'owners', ' omv', 'arf', 'accessories']
df.columns = column_names
res = []
counter = 0
for index, row in df.iterrows():
    info = extract_car_info(row['new_name'])
    if info == (None, None, None):
        counter += 1
        print(row)
    res.append(info)
print(counter)
print(res)
# Out:
# Name                    name
# Price                  price
# Depreciation    depreciation
# Mileage              mileage
# eng_cap              eng_cap
# power                  power
# reg_date            reg_date
# coe_left            coe_left
# owners                owners
#  omv                     omv
# arf                      arf
# accessories      accessories
# new_name            new_name
# Name: 0, dtype: object
# Name            BMW 7 Series Mild Hybrid 735i sDrive Pure Exce...
# Price                                                      537800
# Depreciation                                                50580
# Mileage                                                      3900
# eng_cap                                                      2998
# power                                                         213
# reg_date                                              20-Mar-2023
# coe_left                                                     8.99
# owners                                                          1
#  omv                                                       102460
# arf                                                        165412
# accessories     2023 BMW 735i Pure Excellence PGR ALED, 1 owne...
# new_name                                              Accessories
# Name: 223, dtype: object
# Name                            Toyota GR Yaris 1.6M Circuit Pack
# Price                                                      192888
# Depreciation                                                23940
# Mileage                                                     26000
# eng_cap                                                      1618
# power                                                         192
# reg_date                                              16-Apr-2021
# coe_left                                                     7.07
# owners                                                          3
#  omv                                                        39511
# arf                                                         47316
# accessories     Rocket Auto Trading. Borneo Motors unit. Legal...
# new_name                                              Accessories
# Name: 483, dtype: object
# 3
# [(None, None, None), ('Honda', 'Crossroad', '2008'), ('Subaru', 'Forester', '2013'), ('Honda', 'Shuttle Hybrid', '2015'), ('Toyota', 'Prius', None), ('Audi', 'Q2', '2017'), ('Mitsubishi', 'Outlander', '2014'), ('Volkswagen', 'Touran', '2016'), ('Porsche', 'Panamera', '2009'), ('Mercedes-Benz', 'E300', None), ('Honda', 'Odyssey', '2014'), ('BMW', '7 Series', '2009'), ('Audi', 'Q3', '2016'), ('Audi', 'S3 Sportback', '2009'), ('Maserati', 'GranTurismo', None), ('Mercedes-Benz', 'GLA-Class', '2014'), ('Renault', 'Megane GT', '2017'), ('Honda', 'Civic', '2016'), ('Subaru', 'XV', '2011'), ('Peugeot', '308 SW', '2015'), ('Nissan', 'Qashqai', '2014'), ('Mazda', 'CX-5', '2017'), ('Nissan', 'Elgrand', '2011'), ('Audi', 'Q5', '2009'), ('BMW', 'X1', '2015'), ('BMW', '318i', None), ('Honda', 'HR-V', '2015'), ('Mercedes-Benz', 'E-Class Saloon', '2009'), ('Audi', 'S3 Sportback', '2009'), ('Audi', 'S3 Sportback', '2009'), ('Audi', 'A4 Sedan', '2016'), ('Audi', 'Q3', '2019'), ('Mercedes-Benz', 'E250', None), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Toyota', 'Harrier', '2014'), ('Toyota', 'Camry', '2012'), ('Hyundai', 'Elantra', '2016'), ('Audi', 'A4 Sedan', '2016'), ('Mercedes-Benz', 'E-Class Coupe', '2009'), ('Mercedes-Benz', 'CLA-Class Shooting Brake', '2015'), ('Honda', 'Civic', '2016'), ('Mercedes-Benz', 'C-Class Saloon', '2014'), ('Honda', 'Odyssey', '2014'), ('Mercedes-Benz', 'GLC-Class Coupe Diesel', '2016'), ('BMW', '3 Series Sedan', '2012'), ('Infiniti', 'Q30', '2016'), ('Nissan', 'Latio Sedan', '2005'), ('Volkswagen', 'Golf', '2012'), ('Mercedes-Benz', 'C-Class Coupe', '2018'), ('MINI', 'Cooper S Roadster', '2012'), ('Mercedes-Benz', 'E-Class Saloon Plug-in Hybrid', '2021'), ('Porsche', 'Cayenne', '2010'), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Mercedes-Benz', 'E-Class Saloon', '2004'), ('Volkswagen', 'Scirocco', '2009'), ('Toyota', 'Harrier', None), ('Subaru', 'XV', '2017'), ('Mazda', '6 Sedan', '2013'), ('Kia', 'Cerato K3', '2013'), ('Kia', 'Sorento', '2015'), ('Mercedes-Benz', 'GLB-Class', '2020'), ('Honda', 'Shuttle', '2015'), ('BMW', '7 Series', '2009'), ('Audi', 'A4 Sedan', '2016'), ('Mercedes-Benz', 'CLA-Class', '2013'), ('BMW', 'X1', '2015'), ('Hyundai', 'i30', '2008'), ('Audi', 'A3 Sedan', '2014'), ('Volvo', 'XC40', '2018'), ('MINI', 'Cooper', None), ('Mercedes-Benz', 'GLA-Class', '2014'), ('SEAT', 'Ateca', '2017'), ('SKODA', 'Superb', '2018'), ('Mercedes-Benz', 'GLA-Class', '2014'), ('Subaru', 'Forester', '2013'), ('Bentley', 'Flying Spur', None), ('Honda', 'Odyssey', None), ('Honda', 'Fit', '2017'), ('Peugeot', '3008', '2017'), ('Volvo', 'S60', '2014'), ('McLaren', '720S', None), ('Lexus', 'IS 300', '2016'), ('Volvo', 'V40', '2013'), ('Toyota', 'Harrier', '2014'), ('Toyota', 'Harrier', '2014'), ('Nissan', 'Note', '2013'), ('Bentley', 'Continental', None), ('Nissan', 'Latio Sedan', '2005'), ('BMW', 'X5', '2019'), ('Audi', 'RS 5 Coupe', '2010'), ('Mercedes-Benz', 'B-Class', '2012'), ('Mercedes-Benz', 'C-Class Coupe Mild Hybrid', '2019'), ('Aston', 'Martin DB11', '2016'), ('Audi', 'A3 Sedan', '2014'), ('Honda', 'Fit', '2017'), ('Volvo', 'V40', '2013'), ('Kia', 'Cerato', '2018'), ('Mercedes-Benz', 'C-Class Saloon Mild Hybrid', '2022'), ('Hyundai', 'Elantra', '2016'), ('Mercedes-Benz', 'E-Class Coupe Mild Hybrid', '2019'), ('Honda', 'Freed Hybrid', '2016'), ('Rolls-Royce', 'Cullinan', None), ('Volkswagen', 'Golf', '2012'), ('Mercedes-Benz', 'GLB-Class', '2020'), ('Hyundai', 'Tucson', '2018'), ('Mercedes-Benz', 'S-Class', '2007'), ('Toyota', 'Sienta', '2016'), ('Audi', 'Q5', '2009'), ('Toyota', 'Camry', '2006'), ('Honda', 'Fit Shuttle', '2013'), ('Mazda', '2 Hatchback', '2015'), ('Volkswagen', 'Tiguan', '2008'), ('Porsche', 'Macan', '2014'), ('BMW', '2 Series Active Tourer', '2014'), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Volkswagen', 'Touran Sport', '2008'), ('Honda', 'HR-V', '2015'), ('Lexus', 'SC430', '2007'), ('Volkswagen', 'Golf', '2012'), ('Nissan', 'Qashqai', '2014'), ('Audi', 'R8', None), ('Volkswag ...

# %%
result_df = pd.concat([df, api_df], axis = 1)

output_filename = "combined_used_cars2.csv"

result_df.to_csv(output_filename, index = False)
