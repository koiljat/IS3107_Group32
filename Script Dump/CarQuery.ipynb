# %%
import requests
from tqdm import tqdm
import pandas as pd
import re
import os

# %% [markdown]
# # CarQuery

# %%
BASE_URL = 'https://www.carqueryapi.com/api/0.3'

header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}


def get_makes(year, sold_in_us=1):
    params = {
        'cmd': 'getMakes',
        'year': year,
        'sold_in_us': sold_in_us
    }
    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Makes']  # Adjust based on the actual key for makes

def get_models(make, year=None, sold_in_us=1, body=None):
    params = {
        'cmd': 'getModels',
        'make': make,
        'sold_in_us': sold_in_us
    }
    if year:
        params['year'] = year
    if body:
        params['body'] = body

    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Models']  # Adjust based on the actual key for models

def get_trims(make, model, year=None, trim=None, body=None):
    params = {
        'cmd': 'getTrims',
        'make': make,
        'model' : model
    }
    if year:
        params['year'] = year
    if trim:
        params['trim'] = trim
    if body:
        params['body'] = body

    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()['Trims']  # Adjust based on the actual key for trims

def get_model(model_id):
    params = {
        'cmd': 'getModel',
        'model': model_id
    }
    response = requests.get(BASE_URL, params=params, headers = header)
    response.raise_for_status()
    return response.json()  # Adjust based on how the API returns data for a single model

def extract_car_info(car_string):
    pattern = re.compile(r'^(.*?)\s(.*?)(?:\s\((\d{4})-?\d*\)|\s(\d{4})|$)')
    match = pattern.search(car_string)
    if match:
        make = match.group(1)
        model = match.group(2)
        year = match.group(3) if match.group(3) else match.group(4)
        return make, model, year
    else:
        return None, None, None
    
def process_chunk(chunk):    
    # Set the columns that you want to keep from the API data
    api_columns = [
        'model_make_id', 'model_name', 'model_trim', 'model_year', 'model_body',
        'model_engine_cyl', 'model_engine_fuel', 'model_drive', 'model_transmission_type',
        'model_seats', 'model_weight_kg', 'model_fuel_cap_l'
    ]

    api_data = []

    # Process each row in the DataFrame
    for index, row in chunk.iterrows():
        name = row['model']
        reg_date = row['reg_date']

        name_split = name.split(' ')
        make = name_split[0]
        model = name_split[1]

        year = pd.to_datetime(reg_date).year if pd.notnull(reg_date) else None

        model_info = get_trims(make=make, model=model, year= year)

        if model_info:
            first_trim = model_info[0]  # Safely get the first trim
            # Select only the desired columns
            selected_trim_info = {key: first_trim.get(key, pd.NA) for key in api_columns}
            print(str(index) + str(selected_trim_info))
            api_data.append(selected_trim_info)
        else:
            print(str(index) + " Nothing found")
            placeholder = {key: pd.NA for key in api_columns}
            api_data.append(placeholder)
    
    result_df = pd.concat([chunk, pd.DataFrame(api_data)], axis = 1)
    
    return result_df

# %% [markdown]
# # Loading the data

# %%
data_filename = "../Datasets/merged_dataset.csv"
start_row = 2400 
chunk_size = 1000

chunk = pd.read_csv(data_filename, skiprows= range(1,start_row + 1), nrows=chunk_size, header=0)

# print(chunk)
api_df = process_chunk(chunk)

output_filename = '../Datasets/CarQuery.csv'

# Check if the file exists and has content
if os.path.exists(output_filename) and os.path.getsize(output_filename) > 0:
    header = False  # Don't write header if file already exists
else:
    header = True  # Write header if file doesn't exist

# Append or write the DataFrame to the CSV file
api_df.to_csv(output_filename, mode='a', index=False, header=header)
# Out:
# 0{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 1 Nothing found
# 2{'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# 3 Nothing found
# 4 Nothing found
# 5 Nothing found
# 6 Nothing found
# 7 Nothing found
# 8 Nothing found
# 9{'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2021', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2820', 'model_fuel_cap_l': '13'}
# 10 Nothing found
# 11 Nothing found
# 12{'model_make_id': 'Honda', 'model_name': 'Accord', 'model_trim': 'EX 2dr Coupe (2.4L 4cyl 6M)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3229', 'model_fuel_cap_l': '17'}
# 13 Nothing found
# 14 Nothing found
# 15{'model_make_id': 'Honda', 'model_name': 'Odyssey', 'model_trim': 'EX 4dr Minivan (3.5L 6cyl 6A)', 'model_year': '2016', 'model_body': 'Minivan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4470', 'model_fuel_cap_l': '21'}
# 16{'model_make_id': 'volkswagen', 'model_name': 'Golf', 'model_trim': '2.5L 2-Door', 'model_year': '2013', 'model_body': 'Hatchback', 'model_engine_cyl': '5', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': '5-speed manual', 'model_seats': '5', 'model_weight_kg': '1376', 'model_fuel_cap_l': '55'}
# 17 Nothing found
# 18 Nothing found
# 19 Nothing found
# 20{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 21{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 22 Nothing found
# 23 Nothing found
# 24 Nothing found
# 25 Nothing found
# 26 Nothing found
# 27 Nothing found
# 28 Nothing found
# 29 Nothing found
# 30{'model_make_id': 'Mercedes-Benz', 'model_name': 'SL-Class', 'model_trim': 'SL400 2dr Convertible (3.0L 6cyl Turbo 7A)', 'model_year': '2015', 'model_body': 'Two Seaters', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3836', 'model_fuel_cap_l': '20'}
# 31{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 32 Nothing found
# 33 Nothing found
# 34{'model_make_id': 'Porsche', 'model_name': '911', 'model_trim': 'Carrera 2dr Convertible (3.4L 6cyl 7M)', 'model_year': '2021', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3197', 'model_fuel_cap_l': '17'}
# 35 Nothing found
# 36 Nothing found
# 37 Nothing found
# 38{'model_make_id': 'Hyundai', 'model_name': 'Elantra', 'model_trim': 'Limited 4dr Sedan (1.8L 4cyl 6A)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2818', 'model_fuel_cap_l': '13'}
# 39 Nothing found
# 40{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 41{'model_make_id': 'Mercedes-Benz', 'model_name': 'G-Class', 'model_trim': 'G550 4dr SUV 4WD (5.5L 8cyl 7A)', 'model_year': '2021', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Four Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '5578', 'model_fuel_cap_l': '25'}
# 42 Nothing found
# 43{'model_make_id': 'honda', 'model_name': 'Accord', 'model_trim': '2.0 Comfort', 'model_year': '2008', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1393', 'model_fuel_cap_l': '65'}
# 44{'model_make_id': 'Audi', 'model_name': 'A6', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3726', 'model_fuel_cap_l': '20'}
# 45 Nothing found
# 46{'model_make_id': 'Honda', 'model_name': 'CR-V', 'model_trim': 'EX 4dr SUV (2.4L 4cyl 5A)', 'model_year': '2014', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '1526', 'model_fuel_cap_l': '58'}
# 47{'model_make_id': 'Volkswagen', 'model_name': 'Passat', 'model_trim': 'S 4dr Sedan (1.8L 4cyl Turbo 5M)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3172', 'model_fuel_cap_l': '19'}
# 48{'model_make_id': 'volkswagen', 'model_name': 'Scirocco', 'model_trim': '1.4 Supercharged', 'model_year': '2011', 'model_body': 'Hatchback', 'model_engine_cyl': None, 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1298', 'model_fuel_cap_l': None}
# 49{'model_make_id': 'honda', 'model_name': 'Stream', 'model_trim': '1.7i ES', 'model_year': '2008', 'model_body': 'Minivan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '7', 'model_weight_kg': '1434', 'model_fuel_cap_l': '55'}
# 50{'model_make_id': 'Hyundai', 'model_name': 'Elantra', 'model_trim': 'Limited 4dr Sedan (1.8L 4cyl 6A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2818', 'model_fuel_cap_l': '13'}
# 51{'model_make_id': 'Porsche', 'model_name': 'Macan', 'model_trim': 'S 4dr SUV AWD (3.0L 6cyl Turbo 7AM)', 'model_year': '2021', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '4112', 'model_fuel_cap_l': '20'}
# 52 Nothing found
# 53 Nothing found
# 54{'model_make_id': 'volkswagen', 'model_name': 'Golf', 'model_trim': '1.4 Comfortline', 'model_year': '2008', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1290', 'model_fuel_cap_l': '55'}
# 55 Nothing found
# 56{'model_make_id': 'Volkswagen', 'model_name': 'Golf', 'model_trim': 'TDI S 4dr Hatchback (2.0L 4cyl Turbodiesel 6AM)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3126', 'model_fuel_cap_l': '13'}
# 57{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 58{'model_make_id': 'Audi', 'model_name': 'Q5', 'model_trim': '2.0T Premium Plus quattro 4dr SUV AWD (2.0L 4cyl Turbo 8A)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4079', 'model_fuel_cap_l': '19'}
# 59{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 60 Nothing found
# 61{'model_make_id': 'Porsche', 'model_name': 'Cayenne', 'model_trim': 'Diesel 4dr SUV AWD (3.0L 6cyl Turbodiesel 8A)', 'model_year': '2020', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Diesel', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4652', 'model_fuel_cap_l': '26'}
# 62 Nothing found
# 63 Nothing found
# 64 Nothing found
# 65 Nothing found
# 66{'model_make_id': 'Toyota', 'model_name': 'Yaris', 'model_trim': 'L 2dr Hatchback (1.5L 4cyl 4A)', 'model_year': '2021', 'model_body': 'Subcompact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2335', 'model_fuel_cap_l': None}
# 67 Nothing found
# 68 Nothing found
# 69 Nothing found
# 70{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2020', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 71 Nothing found
# 72{'model_make_id': 'toyota', 'model_name': 'Camry', 'model_trim': '2.2 GL', 'model_year': '2008', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1364', 'model_fuel_cap_l': '70'}
# 73 Nothing found
# 74 Nothing found
# 75 Nothing found
# 76 Nothing found
# 77{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2020', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 78 Nothing found
# 79 Nothing found
# 80 Nothing found
# 81{'model_make_id': 'Mercedes-Benz', 'model_name': 'GLA-Class', 'model_trim': 'GLA250 4dr SUV (2.0L 4cyl Turbo 7AM)', 'model_year': '2020', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 82 Nothing found
# 83{'model_make_id': 'Jaguar', 'model_name': 'XJ', 'model_trim': '4dr Sedan (3.0L 6cyl S/C 8A)', 'model_year': '2017', 'model_body': 'Large Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Flex-Fuel (Premium Unleaded Requ', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3854', 'model_fuel_cap_l': '22'}
# 84 Nothing found
# 85 Nothing found
# 86{'model_make_id': 'honda', 'model_name': 'Civic', 'model_trim': '1.4 3 Door', 'model_year': '2011', 'model_body': 'Hatchback', 'model_engine_cyl': '2', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1249', 'model_fuel_cap_l': None}
# 87 Nothing found
# 88 Nothing found
# 89{'model_make_id': 'Audi', 'model_name': 'Q3', 'model_trim': 'Premium Plus 4dr SUV (2.0L 4cyl Turbo 6A)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3494', 'model_fuel_cap_l': '17'}
# 90 Nothing found
# 91 Nothing found
# 92 Nothing found
# 93{'model_make_id': 'Jeep', 'model_name': 'Cherokee', 'model_trim': 'Latitude 4dr SUV (2.4L 4cyl 9A)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4044', 'model_fuel_cap_l': '16'}
# 94{'model_make_id': 'Toyota', 'model_name': 'Prius', 'model_trim': 'Five 4dr Hatchback (1.8L 4cyl gas/electric hybrid CVT)', 'model_year': '2021', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3042', 'model_fuel_cap_l': '12'}
# 95 Nothing found
# 96 Nothing found
# 97 Nothing found
# 98{'model_make_id': 'Toyota', 'model_name': 'Prius', 'model_trim': 'Five 4dr Hatchback (1.8L 4cyl gas/electric hybrid CVT)', 'model_year': '2021', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3042', 'model_fuel_cap_l': '12'}
# 99 Nothing found
# 100 Nothing found
# 101{'model_make_id': 'audi', 'model_name': 'S5', 'model_trim': '3.0T Premium Plus Quattro', 'model_year': '2010', 'model_body': 'Coupe', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': 'AWD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1955', 'model_fuel_cap_l': '64'}
# 102 Nothing found
# 103 Nothing found
# 104{'model_make_id': 'BMW', 'model_name': 'X1', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3527', 'model_fuel_cap_l': '17'}
# 105{'model_make_id': 'Audi', 'model_name': 'A6', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3726', 'model_fuel_cap_l': '20'}
# 106 Nothing found
# 107 Nothing found
# 108{'model_make_id': 'Porsche', 'model_name': '911', 'model_trim': 'Carrera 2dr Convertible (3.4L 6cyl 7M)', 'model_year': '2021', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3197', 'model_fuel_cap_l': '17'}
# 109 Nothing found
# 110 Nothing found
# 111 Nothing found
# 112 Nothing found
# 113 Nothing found
# 114 Nothing found
# 115 Nothing found
# 116{'model_make_id': 'BMW', 'model_name': 'X3', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2022', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4030', 'model_fuel_cap_l': '18'}
# 117 Nothing found
# 118{'model_make_id': 'Volvo', 'model_name': 'XC60', 'model_trim': '3.2 4dr SUV AWD w/Prod. End 6/14 (3.2L 6cyl 6A)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4251', 'model_fuel_cap_l': '19'}
# 119 Nothing found
# 120{'model_make_id': 'Toyota', 'model_name': 'Prius', 'model_trim': 'Five 4dr Hatchback (1.8L 4cyl gas/electric hybrid CVT)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3042', 'model_fuel_cap_l': '12'}
# 121 Nothing found
# 122 Nothing found
# 123{'model_make_id': 'Audi', 'model_name': 'A6', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2015', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3726', 'model_fuel_cap_l': '20'}
# 124{'model_make_id': 'mitsubishi', 'model_name': 'Colt', 'model_trim': 'CZ3 1.1', 'model_year': '2008', 'model_body': 'Hatchback', 'model_engine_cyl': '3', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1000', 'model_fuel_cap_l': '47'}
# 125 Nothing found
# 126 Nothing found
# 127 Nothing found
# 128 Nothing found
# 129 Nothing found
# 130 Nothing found
# 131 Nothing found
# 132{'model_make_id': 'honda', 'model_name': 'Fit', 'model_trim': '', 'model_year': '2008', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1280', 'model_fuel_cap_l': '41'}
# 133{'model_make_id': 'Toyota', 'model_name': 'RAV4', 'model_trim': 'LE 4dr SUV (2.5L 4cyl 6A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3435', 'model_fuel_cap_l': '16'}
# 134 Nothing found
# 135 Nothing found
# 136 Nothing found
# 137 Nothing found
# 138 Nothing found
# 139 Nothing found
# 140 Nothing found
# 141{'model_make_id': 'Hyundai', 'model_name': 'Tucson', 'model_trim': 'GLS 4dr SUV (2.0L 4cyl 6A)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3232', 'model_fuel_cap_l': '15'}
# 142 Nothing found
# 143{'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3274', 'model_fuel_cap_l': '13'}
# 144 Nothing found
# 145 Nothing found
# 146 Nothing found
# 147{'model_make_id': 'mitsubishi', 'model_name': 'Lancer', 'model_trim': 'DE', 'model_year': '2010', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1320', 'model_fuel_cap_l': '59'}
# 148 Nothing found
# 149 Nothing found
# 150{'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2019', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2820', 'model_fuel_cap_l': '13'}
# 151{'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2020', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3274', 'model_fuel_cap_l': '13'}
# 152{'model_make_id': 'honda', 'model_name': 'Civic', 'model_trim': '1.4 3 Door', 'model_year': '2011', 'model_body': 'Hatchback', 'model_engine_cyl': '2', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1249', 'model_fuel_cap_l': None}
# 153 Nothing found
# 154 Nothing found
# 155{'model_make_id': 'porsche', 'model_name': 'Cayenne', 'model_trim': '', 'model_year': '2011', 'model_body': 'SUV', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1995', 'model_fuel_cap_l': '85'}
# 156 Nothing found
# 157{'model_make_id': 'honda', 'model_name': 'CR-Z', 'model_trim': '', 'model_year': '2011', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline / Electric Hybrid', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1196', 'model_fuel_cap_l': '40'}
# 158{'model_make_id': 'Hyundai', 'model_name': 'Elantra', 'model_trim': 'Limited 4dr Sedan (1.8L 4cyl 6A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2818', 'model_fuel_cap_l': '13'}
# 159 Nothing found
# 160 Nothing found
# 161{'model_make_id': 'porsche', 'model_name': 'Panamera', 'model_trim': '', 'model_year': '2012', 'model_body': 'Hatchback', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': '7-speed automated manual', 'model_seats': '4', 'model_weight_kg': '1760', 'model_fuel_cap_l': '100'}
# 162 Nothing found
# 163{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 164 Nothing found
# 165 Nothing found
# 166 Nothing found
# 167{'model_make_id': 'Toyota', 'model_name': 'RAV4', 'model_trim': 'LE 4dr SUV (2.5L 4cyl 6A)', 'model_year': '2020', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3435', 'model_fuel_cap_l': '16'}
# 168 Nothing found
# 169 Nothing found
# 170 Nothing found
# 171{'model_make_id': 'bentley', 'model_name': 'Continental', 'model_trim': 'Mulliner R', 'model_year': '2005', 'model_body': 'Coupe', 'model_engine_cyl': None, 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Rear', 'model_transmission_type': 'Automatic', 'model_seats': '4', 'model_weight_kg': '2450', 'model_fuel_cap_l': '100'}
# 172 Nothing found
# 173{'model_make_id': 'Mercedes-Benz', 'model_name': 'S-Class', 'model_trim': 'S550 4dr Sedan (4.7L 8cyl Turbo 7A)', 'model_year': '2016', 'model_body': 'Large Cars', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4630', 'model_fuel_cap_l': '21'}
# 174 Nothing found
# 175{'model_make_id': 'MINI', 'model_name': 'Cooper', 'model_trim': '2dr Convertible (1.6L 4cyl 6M)', 'model_year': '2017', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2701', 'model_fuel_cap_l': '13'}
# 176{'model_make_id': 'Mercedes-Benz', 'model_name': 'GLA-Class', 'model_trim': 'GLA250 4dr SUV (2.0L 4cyl Turbo 7AM)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 177 Nothing found
# 178 Nothing found
# 179{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 180{'model_make_id': 'volkswagen', 'model_name': 'Touran', 'model_trim': '1.2', 'model_year': '2011', 'model_body': 'Minivan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '2307', 'model_fuel_cap_l': '60'}
# 181{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 182 Nothing found
# 183{'model_make_id': 'MINI', 'model_name': 'Cooper', 'model_trim': '2dr Convertible (1.6L 4cyl 6M)', 'model_year': '2017', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2701', 'model_fuel_cap_l': '13'}
# 184 Nothing found
# 185 Nothing found
# 186{'model_make_id': 'Honda', 'model_name': 'Odyssey', 'model_trim': 'EX 4dr Minivan (3.5L 6cyl 6A)', 'model_year': '2014', 'model_body': 'Minivan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2028', 'model_fuel_cap_l': '79'}
# 187 Nothing found
# 188 Nothing found
# 189 Nothing found
# 190 Nothing found
# 191{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 192 Nothing found
# 193 Nothing found
# 194{'model_make_id': 'porsche', 'model_name': 'Panamera', 'model_trim': '4', 'model_year': '2013', 'model_body': 'Hatchback', 'model_engine_cyl': '6', 'model_engine_fuel': 'Electric', 'model_drive': 'AWD', 'model_transmission_type': 'Single Speed', 'model_seats': '4', 'model_weight_kg': '1820', 'model_fuel_cap_l': None}
# 195 Nothing found
# 196 Nothing found
# 197{'model_make_id': 'bmw', 'model_name': 'M3', 'model_trim': 'Convertible', 'model_year': '2013', 'model_body': 'Convertible', 'model_engine_cyl': '8', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': '6-speed manual', 'model_seats': None, 'model_weight_kg': '1880', 'model_fuel_cap_l': '63'}
# 198{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2017', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 199 Nothing found
# 200 Nothing found
# 201 Nothing found
# 202 Nothing found
# 203{'model_make_id': 'Porsche', 'model_name': 'Panamera', 'model_trim': '4 4dr Sedan AWD (3.6L 6cyl 7AM)', 'model_year': '2016', 'model_body': 'Large Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '4012', 'model_fuel_cap_l': '21'}
# 204 Nothing found
# 205{'model_make_id': 'honda', 'model_name': 'Civic', 'model_trim': '1.4', 'model_year': '2008', 'model_body': None, 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1240', 'model_fuel_cap_l': '50'}
# 206 Nothing found
# 207{'model_make_id': 'mini', 'model_name': 'Cooper', 'model_trim': '', 'model_year': '2011', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1225', 'model_fuel_cap_l': '50'}
# 208 Nothing found
# 209{'model_make_id': 'mini', 'model_name': 'Cooper', 'model_trim': '', 'model_year': '2011', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1225', 'model_fuel_cap_l': '50'}
# 210 Nothing found
# 211{'model_make_id': 'Mercedes-Benz', 'model_name': 'S-Class', 'model_trim': 'S550 4dr Sedan (4.7L 8cyl Turbo 7A)', 'model_year': '2019', 'model_body': 'Large Cars', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4630', 'model_fuel_cap_l': '21'}
# 212{'model_make_id': 'Honda', 'model_name': 'Civic', 'model_trim': 'EX 2dr Coupe (1.8L 4cyl 5M)', 'model_year': '2020', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2805', 'model_fuel_cap_l': '13'}
# 213{'model_make_id': 'BMW', 'model_name': 'X3', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4030', 'model_fuel_cap_l': '18'}
# 214 Nothing found
# 215{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2020', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '17'}
# 216{'model_make_id': 'BMW', 'model_name': 'X3', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2018', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4030', 'model_fuel_cap_l': '18'}
# 217 Nothing found
# 218{'model_make_id': 'MINI', 'model_name': 'Cooper', 'model_trim': '2dr Convertible (1.6L 4cyl 6M)', 'model_year': '2018', 'model_body': 'Mini Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2701', 'model_fuel_cap_l': '13'}
# 219{'model_make_id': 'Hyundai', 'model_name': 'Elantra', 'model_trim': 'Limited 4dr Sedan (1.8L 4cyl 6A)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2818', 'model_fuel_cap_l': '13'}
# 220{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2016', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 221{'model_make_id': 'audi', 'model_name': 'R8', 'model_trim': '4.2 FSi Quattro', 'model_year': '2007', 'model_body': 'Coupe', 'model_engine_cyl': '8', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'AWD', 'model_transmission_type': 'Manual', 'model_seats': '2', 'model_weight_kg': '1565', 'model_fuel_cap_l': '75'}
# 222 Nothing found
# 223{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 224{'model_make_id': 'Chevrolet', 'model_name': 'Cruze', 'model_trim': '1LT 4dr Sedan (1.4L 4cyl Turbo 6A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3118', 'model_fuel_cap_l': '16'}
# 225 Nothing found
# 226{'model_make_id': 'Porsche', 'model_name': 'Macan', 'model_trim': 'S 4dr SUV AWD (3.0L 6cyl Turbo 7AM)', 'model_year': '2022', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '4112', 'model_fuel_cap_l': '20'}
# 227{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2016', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 228 Nothing found
# 229 Nothing found
# 230{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2019', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 231 Nothing found
# 232 Nothing found
# 233 Nothing found
# 234{'model_make_id': 'Mitsubishi', 'model_name': 'Outlander', 'model_trim': 'ES 4dr SUV (2.4L 4cyl CVT)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3285', 'model_fuel_cap_l': '17'}
# 235 Nothing found
# 236 Nothing found
# 237 Nothing found
# 238 Nothing found
# 239{'model_make_id': 'Kia', 'model_name': 'Rio', 'model_trim': 'EX 4dr Hatchback (1.6L 4cyl 6A)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 240 Nothing found
# 241 Nothing found
# 242{'model_make_id': 'Honda', 'model_name': 'Odyssey', 'model_trim': 'EX 4dr Minivan (3.5L 6cyl 6A)', 'model_year': '2019', 'model_body': 'Minivan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4470', 'model_fuel_cap_l': '21'}
# 243 Nothing found
# 244 Nothing found
# 245 Nothing found
# 246 Nothing found
# 247 Nothing found
# 248{'model_make_id': 'audi', 'model_name': 'TT', 'model_trim': '1.8 TFSi Convertible', 'model_year': '2011', 'model_body': 'Convertible', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': '6-speed automated manual', 'model_seats': '2', 'model_weight_kg': None, 'model_fuel_cap_l': '60'}
# 249{'model_make_id': 'Audi', 'model_name': 'A4', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3516', 'model_fuel_cap_l': '16'}
# 250 Nothing found
# 251 Nothing found
# 252 Nothing found
# 253 Nothing found
# 254 Nothing found
# 255{'model_make_id': 'BMW', 'model_name': 'X5', 'model_trim': 'sDrive35i 4dr SUV (3.0L 6cyl Turbo 8A)', 'model_year': '2021', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 256 Nothing found
# 257 Nothing found
# 258 Nothing found
# 259 Nothing found
# 260 Nothing found
# 261{'model_make_id': 'BMW', 'model_name': 'X3', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2021', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4030', 'model_fuel_cap_l': '18'}
# 262{'model_make_id': 'rolls-royce', 'model_name': 'Phantom', 'model_trim': '', 'model_year': '2011', 'model_body': 'Sedan', 'model_engine_cyl': '12', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Automatic', 'model_seats': '5', 'model_weight_kg': '2630', 'model_fuel_cap_l': '100'}
# 263 Nothing found
# 264 Nothing found
# 265 Nothing found
# 266{'model_make_id': 'BMW', 'model_name': 'X4', 'model_trim': 'xDrive28i 4dr SUV AWD (2.0L 4cyl Turbo 8A)', 'model_year': '2019', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4130', 'model_fuel_cap_l': '18'}
# 267{'model_make_id': 'subaru', 'model_name': 'Impreza', 'model_trim': '2.0 R', 'model_year': '2007', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1375', 'model_fuel_cap_l': '60'}
# 268 Nothing found
# 269 Nothing found
# 270 Nothing found
# 271 Nothing found
# 272{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2022', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 273{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2019', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 274 Nothing found
# 275 Nothing found
# 276 Nothing found
# 277 Nothing found
# 278{'model_make_id': 'mini', 'model_name': 'Cooper', 'model_trim': '', 'model_year': '2010', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1245', 'model_fuel_cap_l': '50'}
# 279{'model_make_id': 'Honda', 'model_name': 'Fit', 'model_trim': 'EX 4dr Hatchback (1.5L 4cyl 6M)', 'model_year': '2019', 'model_body': 'Small Station Wagons', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2573', 'model_fuel_cap_l': '11'}
# 280{'model_make_id': 'Honda', 'model_name': 'Fit', 'model_trim': 'EX 4dr Hatchback (1.5L 4cyl 6M)', 'model_year': '2019', 'model_body': 'Small Station Wagons', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2573', 'model_fuel_cap_l': '11'}
# 281{'model_make_id': 'Mercedes-Benz', 'model_name': 'S-Class', 'model_trim': 'S550 4dr Sedan (4.7L 8cyl Turbo 7A)', 'model_year': '2015', 'model_body': 'Large Cars', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4630', 'model_fuel_cap_l': '21'}
# 282{'model_make_id': 'Mercedes-Benz', 'model_name': 'S-Class', 'model_trim': 'S550 4dr Sedan (4.7L 8cyl Turbo 7A)', 'model_year': '2015', 'model_body': 'Large Cars', 'model_engine_cyl': '8', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4630', 'model_fuel_cap_l': '21'}
# 283 Nothing found
# 284{'model_make_id': 'Hyundai', 'model_name': 'Elantra', 'model_trim': 'Limited 4dr Sedan (1.8L 4cyl 6A)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2818', 'model_fuel_cap_l': '13'}
# 285{'model_make_id': 'honda', 'model_name': 'Stream', 'model_trim': '1.7i ES', 'model_year': '2009', 'model_body': 'Minivan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '7', 'model_weight_kg': '1434', 'model_fuel_cap_l': '55'}
# 286{'model_make_id': 'Audi', 'model_name': 'Q5', 'model_trim': '2.0T Premium Plus quattro 4dr SUV AWD (2.0L 4cyl Turbo 8A)', 'model_year': '2022', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4079', 'model_fuel_cap_l': '19'}
# 287 Nothing found
# 288 Nothing found
# 289 Nothing found
# 290{'model_make_id': 'Toyota', 'model_name': 'Camry', 'model_trim': 'LE 4dr Sedan (2.5L 4cyl 6A)', 'model_year': '2015', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3240', 'model_fuel_cap_l': '17'}
# 291{'model_make_id': 'volkswagen', 'model_name': 'Scirocco', 'model_trim': '1.4 Supercharged', 'model_year': '2009', 'model_body': 'Hatchback', 'model_engine_cyl': None, 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1298', 'model_fuel_cap_l': None}
# 292{'model_make_id': 'jaguar', 'model_name': 'XK', 'model_trim': '4.2 Cabriolet', 'model_year': '2007', 'model_body': 'Convertible', 'model_engine_cyl': '8', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Rear', 'model_transmission_type': 'Automatic', 'model_seats': '4', 'model_weight_kg': '1735', 'model_fuel_cap_l': '71'}
# 293{'model_make_id': 'porsche', 'model_name': 'Cayman', 'model_trim': '', 'model_year': '2008', 'model_body': 'Coupe', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Manual', 'model_seats': '2', 'model_weight_kg': '1300', 'model_fuel_cap_l': '64'}
# 294 Nothing found
# 295 Nothing found
# 296 Nothing found
# 297{'model_make_id': 'Kia', 'model_name': 'Sportage', 'model_trim': 'EX 4dr SUV (2.4L 4cyl 6A)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 298{'model_make_id': 'porsche', 'model_name': 'Cayenne', 'model_trim': '', 'model_year': '2012', 'model_body': 'SUV', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': '4WD', 'model_transmission_type': '6-speed manual', 'model_seats': '5', 'model_weight_kg': '1995', 'model_fuel_cap_l': '85'}
# 299{'model_make_id': 'Jaguar', 'model_name': 'XJ', 'model_trim': '4dr Sedan (3.0L 6cyl S/C 8A)', 'model_year': '2018', 'model_body': 'Large Cars', 'model_engine_cyl': '6', 'model_engine_fuel': 'Flex-Fuel (Premium Unleaded Requ', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3854', 'model_fuel_cap_l': '22'}
# 300{'model_make_id': 'volkswagen', 'model_name': 'Golf', 'model_trim': '1.4 Comfortline', 'model_year': '2008', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1290', 'model_fuel_cap_l': '55'}
# 301 Nothing found
# 302 Nothing found
# 303 Nothing found
# ...
# 403 Nothing found
# 404{'model_make_id': 'Subaru', 'model_name': 'Forester', 'model_trim': '2.0XT Premium 4dr SUV AWD (2.0L 4cyl Turbo CVT)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3624', 'model_fuel_cap_l': '16'}
# 405 Nothing found
# 406{'model_make_id': 'Honda', 'model_name': 'Fit', 'model_trim': 'EX 4dr Hatchback (1.5L 4cyl 6M)', 'model_year': '2021', 'model_body': 'Small Station Wagons', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2573', 'model_fuel_cap_l': '11'}
# 407 Nothing found
# 408{'model_make_id': 'suzuki', 'model_name': 'SX4', 'model_trim': '2', 'model_year': '2009', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1295', 'model_fuel_cap_l': '50'}
# 409 Nothing found
# 410{'model_make_id': 'honda', 'model_name': 'Stream', 'model_trim': '1.7i ES', 'model_year': '2009', 'model_body': 'Minivan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '7', 'model_weight_kg': '1434', 'model_fuel_cap_l': '55'}
# 411{'model_make_id': 'Mercedes-Benz', 'model_name': 'E-Class', 'model_trim': 'E250 Luxury BlueTEC 4dr Sedan (2.1L 4cyl Turbodiesel 7A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 412 Nothing found
# 413 Nothing found
# 414 Nothing found
# 415 Nothing found
# 416 Nothing found
# 417 Nothing found
# 418 Nothing found
# 419{'model_make_id': 'Honda', 'model_name': 'Fit', 'model_trim': 'EX 4dr Hatchback (1.5L 4cyl 6M)', 'model_year': '2020', 'model_body': 'Small Station Wagons', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '2573', 'model_fuel_cap_l': '11'}
# 420{'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2018', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2820', 'model_fuel_cap_l': '13'}
# 421{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '1605', 'model_fuel_cap_l': '66'}
# 422{'model_make_id': 'Porsche', 'model_name': 'Macan', 'model_trim': 'S 4dr SUV AWD (3.0L 6cyl Turbo 7AM)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '4112', 'model_fuel_cap_l': '20'}
# 423{'model_make_id': 'honda', 'model_name': 'Accord', 'model_trim': '2.0 Comfort', 'model_year': '2008', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1393', 'model_fuel_cap_l': '65'}
# 424{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 425{'model_make_id': 'Volkswagen', 'model_name': 'Passat', 'model_trim': 'S 4dr Sedan (1.8L 4cyl Turbo 5M)', 'model_year': '2020', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3172', 'model_fuel_cap_l': '19'}
# 426{'model_make_id': 'audi', 'model_name': 'A6', 'model_trim': '', 'model_year': '2008', 'model_body': 'Sedan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Automatic', 'model_seats': '5', 'model_weight_kg': '1750', 'model_fuel_cap_l': '70'}
# 427{'model_make_id': 'porsche', 'model_name': '911', 'model_trim': 'Carrera', 'model_year': '2011', 'model_body': 'Coupe', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Manual', 'model_seats': '4', 'model_weight_kg': '1389', 'model_fuel_cap_l': '64'}
# 428 Nothing found
# 429 Nothing found
# 430 Nothing found
# 431 Nothing found
# 432{'model_make_id': 'Mercedes-Benz', 'model_name': 'C-Class', 'model_trim': 'C250 2dr Coupe (1.8L 4cyl Turbo 7A)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '1605', 'model_fuel_cap_l': '66'}
# 433 Nothing found
# 434 Nothing found
# 435{'model_make_id': 'Toyota', 'model_name': 'Corolla', 'model_trim': 'L 4dr Sedan (1.8L 4cyl 4A)', 'model_year': '2017', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2820', 'model_fuel_cap_l': '13'}
# 436{'model_make_id': 'kia', 'model_name': 'Cerato', 'model_trim': '1.6 LX', 'model_year': '2009', 'model_body': 'Hatchback', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': None, 'model_seats': '5', 'model_weight_kg': '1253', 'model_fuel_cap_l': '55'}
# 437{'model_make_id': 'toyota', 'model_name': 'Corolla', 'model_trim': 'Automatic', 'model_year': '2012', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': 'Automatic', 'model_seats': '5', 'model_weight_kg': '1240', 'model_fuel_cap_l': '50'}
# 438{'model_make_id': 'Audi', 'model_name': 'Q3', 'model_trim': 'Premium Plus 4dr SUV (2.0L 4cyl Turbo 6A)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3494', 'model_fuel_cap_l': '17'}
# 439{'model_make_id': 'kia', 'model_name': 'Rio', 'model_trim': '1.3 RS', 'model_year': '2008', 'model_body': None, 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline - Premium', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1144', 'model_fuel_cap_l': '45'}
# 440 Nothing found
# 441{'model_make_id': 'BMW', 'model_name': 'X4', 'model_trim': 'xDrive28i 4dr SUV AWD (2.0L 4cyl Turbo 8A)', 'model_year': '2015', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4130', 'model_fuel_cap_l': '18'}
# 442 Nothing found
# 443 Nothing found
# 444 Nothing found
# 445 Nothing found
# 446 Nothing found
# 447 Nothing found
# 448 Nothing found
# 449 Nothing found
# 450 Nothing found
# 451 Nothing found
# 452 Nothing found
# 453{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 454 Nothing found
# 455{'model_make_id': 'Kia', 'model_name': 'Sportage', 'model_trim': 'EX 4dr SUV (2.4L 4cyl 6A)', 'model_year': '2017', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 456 Nothing found
# 457 Nothing found
# 458 Nothing found
# 459{'model_make_id': 'bmw', 'model_name': 'Z4', 'model_trim': 'sDrive20i', 'model_year': '2011', 'model_body': 'Convertible', 'model_engine_cyl': '4', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Rear', 'model_transmission_type': 'Manual', 'model_seats': '2', 'model_weight_kg': '1480', 'model_fuel_cap_l': '55'}
# 460 Nothing found
# 461{'model_make_id': 'Volkswagen', 'model_name': 'Golf', 'model_trim': 'TDI S 4dr Hatchback (2.0L 4cyl Turbodiesel 6AM)', 'model_year': '2016', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3126', 'model_fuel_cap_l': '13'}
# 462 Nothing found
# 463 Nothing found
# 464{'model_make_id': 'bmw', 'model_name': 'X6', 'model_trim': 'ActiveHybrid', 'model_year': '2012', 'model_body': 'SUV', 'model_engine_cyl': '8', 'model_engine_fuel': 'Gasoline / Electric Hybrid', 'model_drive': 'AWD', 'model_transmission_type': 'Automatic', 'model_seats': '4', 'model_weight_kg': '2615', 'model_fuel_cap_l': '85'}
# 465 Nothing found
# 466{'model_make_id': 'toyota', 'model_name': 'Previa', 'model_trim': '2.0 D-4D', 'model_year': '2008', 'model_body': 'Minivan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '7', 'model_weight_kg': '1775', 'model_fuel_cap_l': '75'}
# 467{'model_make_id': 'BMW', 'model_name': 'X5', 'model_trim': 'sDrive35i 4dr SUV (3.0L 6cyl Turbo 8A)', 'model_year': '2015', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '6', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': None}
# 468 Nothing found
# 469{'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '1480', 'model_fuel_cap_l': '50'}
# 470 Nothing found
# 471{'model_make_id': 'audi', 'model_name': 'A6', 'model_trim': '2.0 TDI', 'model_year': '2012', 'model_body': 'Sedan', 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front', 'model_transmission_type': None, 'model_seats': '5', 'model_weight_kg': None, 'model_fuel_cap_l': '75'}
# 472{'model_make_id': 'BMW', 'model_name': 'X3', 'model_trim': 'sDrive28i 4dr SUV (2.0L 4cyl Turbo 8A)', 'model_year': '2020', 'model_body': 'Sport Utility Vehicles', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Rear Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4030', 'model_fuel_cap_l': '18'}
# 473 Nothing found
# 474 Nothing found
# 475 Nothing found
# 476{'model_make_id': 'Audi', 'model_name': 'A5', 'model_trim': '2.0T Premium Plus quattro 2dr Convertible AWD (2.0L 4cyl Turbo 8', 'model_year': '2021', 'model_body': 'Subcompact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'All Wheel Drive', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4045', 'model_fuel_cap_l': '16'}
# 477 Nothing found
# 478{'model_make_id': 'Volkswagen', 'model_name': 'Passat', 'model_trim': 'S 4dr Sedan (1.8L 4cyl Turbo 5M)', 'model_year': '2019', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '3172', 'model_fuel_cap_l': '19'}
# 479 Nothing found
# 480{'model_make_id': 'Mercedes-Benz', 'model_name': 'CLA-Class', 'model_trim': 'CLA250 4dr Sedan (2.0L 4cyl Turbo 7AM)', 'model_year': '2018', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': '3274', 'model_fuel_cap_l': '13'}
# 481{'model_make_id': 'volvo', 'model_name': 'XC90', 'model_trim': '3.2', 'model_year': '2013', 'model_body': 'SUV', 'model_engine_cyl': '6', 'model_engine_fuel': 'Gasoline', 'model_drive': 'Front', 'model_transmission_type': '6-speed manual', 'model_seats': '7', 'model_weight_kg': '2137', 'model_fuel_cap_l': None}
# 482 Nothing found
# 483{'model_make_id': 'Honda', 'model_name': 'Odyssey', 'model_trim': 'EX 4dr Minivan (3.5L 6cyl 6A)', 'model_year': '2017', 'model_body': 'Minivan', 'model_engine_cyl': '6', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '4470', 'model_fuel_cap_l': '21'}
# 484 Nothing found
# 485 Nothing found
# 486 Nothing found
# 487 Nothing found
# 488{'model_make_id': 'Audi', 'model_name': 'A3', 'model_trim': '1.8 TFSI Premium 2dr Convertible (1.8L 4cyl Turbo 6AM)', 'model_year': '2015', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Recommended)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automated Manual', 'model_seats': None, 'model_weight_kg': None, 'model_fuel_cap_l': '13'}
# 489{'model_make_id': 'Volkswagen', 'model_name': 'Jetta', 'model_trim': '4dr Sedan (2.0L 4cyl 5M)', 'model_year': '2014', 'model_body': 'Compact Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Manual', 'model_seats': None, 'model_weight_kg': '1272', 'model_fuel_cap_l': '55'}
# 490{'model_make_id': 'Audi', 'model_name': 'A6', 'model_trim': '2.0T Premium 4dr Sedan (2.0L 4cyl Turbo CVT)', 'model_year': '2021', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Premium Unleaded (Required)', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '3726', 'model_fuel_cap_l': '20'}
# 491 Nothing found
# 492{'model_make_id': 'toyota', 'model_name': 'Corolla', 'model_trim': '1.4 D-4D', 'model_year': '2007', 'model_body': None, 'model_engine_cyl': '4', 'model_engine_fuel': 'Diesel', 'model_drive': 'Front', 'model_transmission_type': 'Manual', 'model_seats': '5', 'model_weight_kg': '1190', 'model_fuel_cap_l': '55'}
# 493 Nothing found
# 494 Nothing found
# 495 Nothing found
# 496 Nothing found
# 497{'model_make_id': 'Hyundai', 'model_name': 'Elantra', 'model_trim': 'Limited 4dr Sedan (1.8L 4cyl 6A)', 'model_year': '2015', 'model_body': 'Midsize Cars', 'model_engine_cyl': '4', 'model_engine_fuel': 'Regular Unleaded', 'model_drive': 'Front Wheel Driv', 'model_transmission_type': 'Automatic', 'model_seats': None, 'model_weight_kg': '2818', 'model_fuel_cap_l': '13'}
# 498 Nothing found
# 499 Nothing found

# %%
data_filename = "../Dataset/merged_dataset.csv"

df = pd.read_csv(data_filename, nrows= 500, header= None)

column_names = ['name', 'price', 'depreciation', 'mileage', 'eng_cap', 'power', 'reg_date', 'coe_left', 'owners', ' omv', 'arf', 'accessories']
df.columns = column_names
res = []
counter = 0
for index, row in df.iterrows():
    info = extract_car_info(row['new_name'])
    if info == (None, None, None):
        counter += 1
        print(row)
    res.append(info)
print(counter)
print(res)
# Out:
# Name                    name
# Price                  price
# Depreciation    depreciation
# Mileage              mileage
# eng_cap              eng_cap
# power                  power
# reg_date            reg_date
# coe_left            coe_left
# owners                owners
#  omv                     omv
# arf                      arf
# accessories      accessories
# new_name            new_name
# Name: 0, dtype: object
# Name            BMW 7 Series Mild Hybrid 735i sDrive Pure Exce...
# Price                                                      537800
# Depreciation                                                50580
# Mileage                                                      3900
# eng_cap                                                      2998
# power                                                         213
# reg_date                                              20-Mar-2023
# coe_left                                                     8.99
# owners                                                          1
#  omv                                                       102460
# arf                                                        165412
# accessories     2023 BMW 735i Pure Excellence PGR ALED, 1 owne...
# new_name                                              Accessories
# Name: 223, dtype: object
# Name                            Toyota GR Yaris 1.6M Circuit Pack
# Price                                                      192888
# Depreciation                                                23940
# Mileage                                                     26000
# eng_cap                                                      1618
# power                                                         192
# reg_date                                              16-Apr-2021
# coe_left                                                     7.07
# owners                                                          3
#  omv                                                        39511
# arf                                                         47316
# accessories     Rocket Auto Trading. Borneo Motors unit. Legal...
# new_name                                              Accessories
# Name: 483, dtype: object
# 3
# [(None, None, None), ('Honda', 'Crossroad', '2008'), ('Subaru', 'Forester', '2013'), ('Honda', 'Shuttle Hybrid', '2015'), ('Toyota', 'Prius', None), ('Audi', 'Q2', '2017'), ('Mitsubishi', 'Outlander', '2014'), ('Volkswagen', 'Touran', '2016'), ('Porsche', 'Panamera', '2009'), ('Mercedes-Benz', 'E300', None), ('Honda', 'Odyssey', '2014'), ('BMW', '7 Series', '2009'), ('Audi', 'Q3', '2016'), ('Audi', 'S3 Sportback', '2009'), ('Maserati', 'GranTurismo', None), ('Mercedes-Benz', 'GLA-Class', '2014'), ('Renault', 'Megane GT', '2017'), ('Honda', 'Civic', '2016'), ('Subaru', 'XV', '2011'), ('Peugeot', '308 SW', '2015'), ('Nissan', 'Qashqai', '2014'), ('Mazda', 'CX-5', '2017'), ('Nissan', 'Elgrand', '2011'), ('Audi', 'Q5', '2009'), ('BMW', 'X1', '2015'), ('BMW', '318i', None), ('Honda', 'HR-V', '2015'), ('Mercedes-Benz', 'E-Class Saloon', '2009'), ('Audi', 'S3 Sportback', '2009'), ('Audi', 'S3 Sportback', '2009'), ('Audi', 'A4 Sedan', '2016'), ('Audi', 'Q3', '2019'), ('Mercedes-Benz', 'E250', None), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Toyota', 'Harrier', '2014'), ('Toyota', 'Camry', '2012'), ('Hyundai', 'Elantra', '2016'), ('Audi', 'A4 Sedan', '2016'), ('Mercedes-Benz', 'E-Class Coupe', '2009'), ('Mercedes-Benz', 'CLA-Class Shooting Brake', '2015'), ('Honda', 'Civic', '2016'), ('Mercedes-Benz', 'C-Class Saloon', '2014'), ('Honda', 'Odyssey', '2014'), ('Mercedes-Benz', 'GLC-Class Coupe Diesel', '2016'), ('BMW', '3 Series Sedan', '2012'), ('Infiniti', 'Q30', '2016'), ('Nissan', 'Latio Sedan', '2005'), ('Volkswagen', 'Golf', '2012'), ('Mercedes-Benz', 'C-Class Coupe', '2018'), ('MINI', 'Cooper S Roadster', '2012'), ('Mercedes-Benz', 'E-Class Saloon Plug-in Hybrid', '2021'), ('Porsche', 'Cayenne', '2010'), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Mercedes-Benz', 'E-Class Saloon', '2004'), ('Volkswagen', 'Scirocco', '2009'), ('Toyota', 'Harrier', None), ('Subaru', 'XV', '2017'), ('Mazda', '6 Sedan', '2013'), ('Kia', 'Cerato K3', '2013'), ('Kia', 'Sorento', '2015'), ('Mercedes-Benz', 'GLB-Class', '2020'), ('Honda', 'Shuttle', '2015'), ('BMW', '7 Series', '2009'), ('Audi', 'A4 Sedan', '2016'), ('Mercedes-Benz', 'CLA-Class', '2013'), ('BMW', 'X1', '2015'), ('Hyundai', 'i30', '2008'), ('Audi', 'A3 Sedan', '2014'), ('Volvo', 'XC40', '2018'), ('MINI', 'Cooper', None), ('Mercedes-Benz', 'GLA-Class', '2014'), ('SEAT', 'Ateca', '2017'), ('SKODA', 'Superb', '2018'), ('Mercedes-Benz', 'GLA-Class', '2014'), ('Subaru', 'Forester', '2013'), ('Bentley', 'Flying Spur', None), ('Honda', 'Odyssey', None), ('Honda', 'Fit', '2017'), ('Peugeot', '3008', '2017'), ('Volvo', 'S60', '2014'), ('McLaren', '720S', None), ('Lexus', 'IS 300', '2016'), ('Volvo', 'V40', '2013'), ('Toyota', 'Harrier', '2014'), ('Toyota', 'Harrier', '2014'), ('Nissan', 'Note', '2013'), ('Bentley', 'Continental', None), ('Nissan', 'Latio Sedan', '2005'), ('BMW', 'X5', '2019'), ('Audi', 'RS 5 Coupe', '2010'), ('Mercedes-Benz', 'B-Class', '2012'), ('Mercedes-Benz', 'C-Class Coupe Mild Hybrid', '2019'), ('Aston', 'Martin DB11', '2016'), ('Audi', 'A3 Sedan', '2014'), ('Honda', 'Fit', '2017'), ('Volvo', 'V40', '2013'), ('Kia', 'Cerato', '2018'), ('Mercedes-Benz', 'C-Class Saloon Mild Hybrid', '2022'), ('Hyundai', 'Elantra', '2016'), ('Mercedes-Benz', 'E-Class Coupe Mild Hybrid', '2019'), ('Honda', 'Freed Hybrid', '2016'), ('Rolls-Royce', 'Cullinan', None), ('Volkswagen', 'Golf', '2012'), ('Mercedes-Benz', 'GLB-Class', '2020'), ('Hyundai', 'Tucson', '2018'), ('Mercedes-Benz', 'S-Class', '2007'), ('Toyota', 'Sienta', '2016'), ('Audi', 'Q5', '2009'), ('Toyota', 'Camry', '2006'), ('Honda', 'Fit Shuttle', '2013'), ('Mazda', '2 Hatchback', '2015'), ('Volkswagen', 'Tiguan', '2008'), ('Porsche', 'Macan', '2014'), ('BMW', '2 Series Active Tourer', '2014'), ('Mercedes-Benz', 'E-Class Saloon', '2016'), ('Volkswagen', 'Touran Sport', '2008'), ('Honda', 'HR-V', '2015'), ('Lexus', 'SC430', '2007'), ('Volkswagen', 'Golf', '2012'), ('Nissan', 'Qashqai', '2014'), ('Audi', 'R8', None), ('Volkswag ...

# %%
result_df = pd.concat([df, api_df], axis = 1)

output_filename = "combined_used_cars2.csv"

result_df.to_csv(output_filename, index = False)
